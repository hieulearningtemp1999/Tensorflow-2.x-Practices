# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Tensorflow-2.x-Practices/Image Classification on CIFAR10
# Out:
# /content/gdrive/My Drive/Tensorflow-2.x-Practices/Image Classification on CIFAR10

# %%
# !python main.py -m "vgg13" -b 256 -lr 0.01 -e 300
# Out:
# 2021-10-05 15:09:45.998668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:46.257670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:46.258298: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.222584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.223235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.223798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.224402: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-10-05 15:09:49.224471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2021-10-05 15:09:49.228334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.228992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.229527: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.230336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.230909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.231429: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.231989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.232536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 15:09:49.233039: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Device :  /device:GPU:0
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step
# Training samples :  50000
# Testing samples : 10000
# tcmalloc: large alloc 1228800000 bytes == 0x564a8f01a000 @  0x7f66daab51e7 0x7f66d863546e 0x7f66d8685c7b 0x7f66d8685d18 0x7f66d8741d79 0x7f66d8744e4c 0x7f66d8863e7f 0x7f66d8869fb5 0x7f66d886be3d 0x7f66d886d516 0x564a6b2ba720 0x564a6b2ba2f9 0x7f66d874c0db 0x564a6b3a30b2 0x564a6b32962d 0x564a6b3279ee 0x564a6b2babda 0x564a6b329737 0x564a6b3279ee 0x564a6b1f9e2b 0x564a6b329fe4 0x564a6b3279ee 0x564a6b1f9e2b 0x7f66d8672ef7 0x564a6b2b9437 0x564a6b2b9240 0x564a6b32c973 0x564a6b3279ee 0x564a6b2babda 0x564a6b329737 0x564a6b3279ee
# tcmalloc: large alloc 1228800000 bytes == 0x564a8f01a000 @  0x7f66daab51e7 0x7f66d863546e 0x7f66d8685c7b 0x7f66d8685d18 0x7f66d8741d79 0x7f66d8744e4c 0x7f66d8863e7f 0x7f66d8869fb5 0x7f66d886be3d 0x7f66d886d516 0x564a6b2ba720 0x564a6b2ba2f9 0x7f66d874c0db 0x564a6b3a3113 0x564a6b32962d 0x564a6b3279ee 0x564a6b3276f3 0x564a6b3f14c2 0x564a6b3f183d 0x564a6b3f16e6 0x564a6b3c9163 0x564a6b3c8e0c 0x7f66d989fbf7 0x564a6b3c8cea
# Epoch : 1/300, Learning Rate : 0.009999999776482582
# TRAINING...
#   0% 0/196 [00:00<?, ?it/s]2021-10-05 15:10:07.082242: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-05 15:10:11.098528: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 100% 196/196 [00:31<00:00,  6.25it/s, train_loss_batch=tf.Tensor(1.378114, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 22.63it/s, test_loss_batch=tf.Tensor(1.3749998, shape=(), dtype=float32)]
# Train Loss : 1.5889322757720947, Train Acc : 41.31800079345703
# Test Loss :1.207019567489624, Test Acc: 56.730003356933594
# Best Acc : 56.730003356933594
#
# Epoch : 2/300, Learning Rate : 0.009998040273785591
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.24it/s, train_loss_batch=tf.Tensor(1.1680152, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.09it/s, test_loss_batch=tf.Tensor(1.232291, shape=(), dtype=float32)]
# Train Loss : 1.2627472877502441, Train Acc : 54.51599884033203
# Test Loss :1.0021899938583374, Test Acc: 64.1300048828125
# Best Acc : 64.1300048828125
#
# Epoch : 3/300, Learning Rate : 0.009996081702411175
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.8622421, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 51.65it/s, test_loss_batch=tf.Tensor(0.86089134, shape=(), dtype=float32)]
# Train Loss : 1.0812901258468628, Train Acc : 61.25400161743164
# Test Loss :0.8363441228866577, Test Acc: 70.30000305175781
# Best Acc : 70.30000305175781
#
# Epoch : 4/300, Learning Rate : 0.009994122199714184
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.72it/s, train_loss_batch=tf.Tensor(0.8133198, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.56it/s, test_loss_batch=tf.Tensor(0.8873172, shape=(), dtype=float32)]
# Train Loss : 0.9628410339355469, Train Acc : 65.83000183105469
# Test Loss :0.7443658113479614, Test Acc: 74.2699966430664
# Best Acc : 74.2699966430664
#
# Epoch : 5/300, Learning Rate : 0.009992165490984917
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.72it/s, train_loss_batch=tf.Tensor(0.8146635, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.37it/s, test_loss_batch=tf.Tensor(0.9622448, shape=(), dtype=float32)]
# Train Loss : 0.8796552419662476, Train Acc : 69.24800109863281
# Test Loss :0.685861349105835, Test Acc: 76.25
# Best Acc : 76.25
#
# Epoch : 6/300, Learning Rate : 0.00999020878225565
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.67it/s, train_loss_batch=tf.Tensor(0.6348668, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.82it/s, test_loss_batch=tf.Tensor(1.0655771, shape=(), dtype=float32)]
# Train Loss : 0.8126311898231506, Train Acc : 71.4020004272461
# Test Loss :0.6489414572715759, Test Acc: 77.72000122070312
# Best Acc : 77.72000122070312
#
# Epoch : 7/300, Learning Rate : 0.009988253936171532
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.74it/s, train_loss_batch=tf.Tensor(0.62524784, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.14it/s, test_loss_batch=tf.Tensor(0.9625232, shape=(), dtype=float32)]
# Train Loss : 0.7613552808761597, Train Acc : 73.33999633789062
# Test Loss :0.5963224172592163, Test Acc: 79.0199966430664
# Best Acc : 79.0199966430664
#
# Epoch : 8/300, Learning Rate : 0.009986299090087414
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.62014514, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.63it/s, test_loss_batch=tf.Tensor(0.8685994, shape=(), dtype=float32)]
# Train Loss : 0.7133513689041138, Train Acc : 75.10799407958984
# Test Loss :0.5664083361625671, Test Acc: 80.4000015258789
# Best Acc : 80.4000015258789
#
# Epoch : 9/300, Learning Rate : 0.00998434517532587
# TRAINING...
# 100% 196/196 [00:20<00:00,  9.41it/s, train_loss_batch=tf.Tensor(0.6888439, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.52it/s, test_loss_batch=tf.Tensor(0.8324805, shape=(), dtype=float32)]
# Train Loss : 0.6741254925727844, Train Acc : 76.70000457763672
# Test Loss :0.5295406579971313, Test Acc: 81.86000061035156
# Best Acc : 81.86000061035156
#
# Epoch : 10/300, Learning Rate : 0.009982390329241753
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.5621084, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.64it/s, test_loss_batch=tf.Tensor(1.0057962, shape=(), dtype=float32)]
# Train Loss : 0.6398762464523315, Train Acc : 77.66999816894531
# Test Loss :0.5224068760871887, Test Acc: 82.56000518798828
# Best Acc : 82.56000518798828
#
# Epoch : 11/300, Learning Rate : 0.009980437345802784
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.52200735, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.94it/s, test_loss_batch=tf.Tensor(0.76686674, shape=(), dtype=float32)]
# Train Loss : 0.6136322021484375, Train Acc : 78.4280014038086
# Test Loss :0.5004757642745972, Test Acc: 82.86000061035156
# Best Acc : 82.86000061035156
#
# Epoch : 12/300, Learning Rate : 0.009978486225008965
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.67it/s, train_loss_batch=tf.Tensor(0.4313352, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.49it/s, test_loss_batch=tf.Tensor(0.915615, shape=(), dtype=float32)]
# Train Loss : 0.5883964896202087, Train Acc : 79.52400207519531
# Test Loss :0.4932260513305664, Test Acc: 83.26000213623047
# Best Acc : 83.26000213623047
#
# Epoch : 13/300, Learning Rate : 0.009976535104215145
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.72it/s, train_loss_batch=tf.Tensor(0.4593742, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.04it/s, test_loss_batch=tf.Tensor(0.65623796, shape=(), dtype=float32)]
# Train Loss : 0.5597271919250488, Train Acc : 80.47200012207031
# Test Loss :0.4663364887237549, Test Acc: 84.25
# Best Acc : 84.25
#
# Epoch : 14/300, Learning Rate : 0.0099745849147439
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.66it/s, train_loss_batch=tf.Tensor(0.40026587, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.94it/s, test_loss_batch=tf.Tensor(0.7196958, shape=(), dtype=float32)]
# Train Loss : 0.5403884053230286, Train Acc : 81.14600372314453
# Test Loss :0.44844937324523926, Test Acc: 84.62999725341797
# Best Acc : 84.62999725341797
#
# Epoch : 15/300, Learning Rate : 0.00997263565659523
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.65it/s, train_loss_batch=tf.Tensor(0.3978743, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.94it/s, test_loss_batch=tf.Tensor(0.67479914, shape=(), dtype=float32)]
# Train Loss : 0.5216343402862549, Train Acc : 81.80000305175781
# Test Loss :0.4408687949180603, Test Acc: 85.05999755859375
# Best Acc : 85.05999755859375
#
# Epoch : 16/300, Learning Rate : 0.009970685467123985
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.74it/s, train_loss_batch=tf.Tensor(0.32717037, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.85it/s, test_loss_batch=tf.Tensor(0.6276778, shape=(), dtype=float32)]
# Train Loss : 0.5065683126449585, Train Acc : 82.20800018310547
# Test Loss :0.43185901641845703, Test Acc: 85.29999542236328
# Best Acc : 85.29999542236328
#
# Epoch : 17/300, Learning Rate : 0.00996873714029789
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.36309022, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.04it/s, test_loss_batch=tf.Tensor(0.7472494, shape=(), dtype=float32)]
# Train Loss : 0.4862009882926941, Train Acc : 82.86799621582031
# Test Loss :0.4266813397407532, Test Acc: 85.87999725341797
# Best Acc : 85.87999725341797
#
# Epoch : 18/300, Learning Rate : 0.009966790676116943
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.30344382, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.79it/s, test_loss_batch=tf.Tensor(0.94924486, shape=(), dtype=float32)]
# Train Loss : 0.47320979833602905, Train Acc : 83.6259994506836
# Test Loss :0.4265359342098236, Test Acc: 85.66999816894531
# Best Acc : 85.87999725341797
#
# Epoch : 19/300, Learning Rate : 0.009964844211935997
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.409868, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.26it/s, test_loss_batch=tf.Tensor(0.6234257, shape=(), dtype=float32)]
# Train Loss : 0.4623354971408844, Train Acc : 84.0219955444336
# Test Loss :0.40587490797042847, Test Acc: 86.31999969482422
# Best Acc : 86.31999969482422
#
# Epoch : 20/300, Learning Rate : 0.00996289774775505
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.39171165, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.81it/s, test_loss_batch=tf.Tensor(0.78233343, shape=(), dtype=float32)]
# Train Loss : 0.4521312415599823, Train Acc : 84.26000213623047
# Test Loss :0.40611594915390015, Test Acc: 86.43000030517578
# Best Acc : 86.43000030517578
#
# Epoch : 21/300, Learning Rate : 0.009960953146219254
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.78it/s, train_loss_batch=tf.Tensor(0.30807108, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.65it/s, test_loss_batch=tf.Tensor(0.4610892, shape=(), dtype=float32)]
# Train Loss : 0.4330412447452545, Train Acc : 84.93800354003906
# Test Loss :0.38628900051116943, Test Acc: 87.19000244140625
# Best Acc : 87.19000244140625
#
# Epoch : 22/300, Learning Rate : 0.009959007613360882
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.77it/s, train_loss_batch=tf.Tensor(0.319144, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.54it/s, test_loss_batch=tf.Tensor(0.45466998, shape=(), dtype=float32)]
# Train Loss : 0.42463570833206177, Train Acc : 85.14599609375
# Test Loss :0.3817996084690094, Test Acc: 86.79999542236328
# Best Acc : 87.19000244140625
#
# Epoch : 23/300, Learning Rate : 0.009957064874470234
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.3571481, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.62it/s, test_loss_batch=tf.Tensor(0.37369508, shape=(), dtype=float32)]
# Train Loss : 0.4112221896648407, Train Acc : 85.77400207519531
# Test Loss :0.38341331481933594, Test Acc: 86.65999603271484
# Best Acc : 87.19000244140625
#
# Epoch : 24/300, Learning Rate : 0.009955122135579586
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.88it/s, train_loss_batch=tf.Tensor(0.38855976, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.33it/s, test_loss_batch=tf.Tensor(0.78448737, shape=(), dtype=float32)]
# Train Loss : 0.3999158442020416, Train Acc : 85.88200378417969
# Test Loss :0.388653427362442, Test Acc: 87.16999816894531
# Best Acc : 87.19000244140625
#
# Epoch : 25/300, Learning Rate : 0.009953180328011513
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.91it/s, train_loss_batch=tf.Tensor(0.20428915, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.24it/s, test_loss_batch=tf.Tensor(0.7115201, shape=(), dtype=float32)]
# Train Loss : 0.396395742893219, Train Acc : 86.03600311279297
# Test Loss :0.3714689314365387, Test Acc: 87.79000091552734
# Best Acc : 87.79000091552734
#
# Epoch : 26/300, Learning Rate : 0.00995123852044344
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.93it/s, train_loss_batch=tf.Tensor(0.3560028, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.21it/s, test_loss_batch=tf.Tensor(0.3290416, shape=(), dtype=float32)]
# Train Loss : 0.38165879249572754, Train Acc : 86.66799926757812
# Test Loss :0.35945090651512146, Test Acc: 87.86000061035156
# Best Acc : 87.86000061035156
#
# Epoch : 27/300, Learning Rate : 0.009949298575520515
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.85it/s, train_loss_batch=tf.Tensor(0.25255132, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.52it/s, test_loss_batch=tf.Tensor(0.48304138, shape=(), dtype=float32)]
# Train Loss : 0.3751600980758667, Train Acc : 86.83999633789062
# Test Loss :0.35814204812049866, Test Acc: 88.01000213623047
# Best Acc : 88.01000213623047
#
# Epoch : 28/300, Learning Rate : 0.009947357699275017
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.69it/s, train_loss_batch=tf.Tensor(0.28216362, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.27it/s, test_loss_batch=tf.Tensor(0.4722876, shape=(), dtype=float32)]
# Train Loss : 0.36382317543029785, Train Acc : 87.27799987792969
# Test Loss :0.35928115248680115, Test Acc: 88.09000396728516
# Best Acc : 88.09000396728516
#
# Epoch : 29/300, Learning Rate : 0.009945418685674667
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.84it/s, train_loss_batch=tf.Tensor(0.17486335, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.00it/s, test_loss_batch=tf.Tensor(0.7763953, shape=(), dtype=float32)]
# Train Loss : 0.35212114453315735, Train Acc : 87.51000213623047
# Test Loss :0.37352219223976135, Test Acc: 87.73999786376953
# Best Acc : 88.09000396728516
#
# Epoch : 30/300, Learning Rate : 0.009943480603396893
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.21951604, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.43it/s, test_loss_batch=tf.Tensor(0.5137502, shape=(), dtype=float32)]
# Train Loss : 0.349103718996048, Train Acc : 87.87000274658203
# Test Loss :0.35971158742904663, Test Acc: 88.12999725341797
# Best Acc : 88.12999725341797
#
# Epoch : 31/300, Learning Rate : 0.007456157822161913
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.24199215, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.69it/s, test_loss_batch=tf.Tensor(0.61808825, shape=(), dtype=float32)]
# Train Loss : 0.32387787103652954, Train Acc : 88.79199981689453
# Test Loss :0.3493630290031433, Test Acc: 88.3800048828125
# Best Acc : 88.3800048828125
#
# Epoch : 32/300, Learning Rate : 0.0074547054246068
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.77it/s, train_loss_batch=tf.Tensor(0.19710198, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.27it/s, test_loss_batch=tf.Tensor(0.5056696, shape=(), dtype=float32)]
# Train Loss : 0.3087550103664398, Train Acc : 89.23799896240234
# Test Loss :0.3443637788295746, Test Acc: 88.88999938964844
# Best Acc : 88.88999938964844
#
# Epoch : 33/300, Learning Rate : 0.0074532534927129745
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.13371636, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.77it/s, test_loss_batch=tf.Tensor(0.52208817, shape=(), dtype=float32)]
# Train Loss : 0.3024021089076996, Train Acc : 89.41799926757812
# Test Loss :0.338674932718277, Test Acc: 88.97000122070312
# Best Acc : 88.97000122070312
#
# Epoch : 34/300, Learning Rate : 0.007451801095157862
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.14551808, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 30.47it/s, test_loss_batch=tf.Tensor(0.698122, shape=(), dtype=float32)]
# Train Loss : 0.2929462194442749, Train Acc : 89.73400115966797
# Test Loss :0.3456048369407654, Test Acc: 88.77999877929688
# Best Acc : 88.97000122070312
#
# Epoch : 35/300, Learning Rate : 0.007450350560247898
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.73it/s, train_loss_batch=tf.Tensor(0.16003723, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.49it/s, test_loss_batch=tf.Tensor(0.6634489, shape=(), dtype=float32)]
# Train Loss : 0.28722745180130005, Train Acc : 89.84600067138672
# Test Loss :0.3365122973918915, Test Acc: 88.68000030517578
# Best Acc : 88.97000122070312
#
# Epoch : 36/300, Learning Rate : 0.0074489000253379345
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.17653903, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.29it/s, test_loss_batch=tf.Tensor(0.49538535, shape=(), dtype=float32)]
# Train Loss : 0.2884230613708496, Train Acc : 89.89800262451172
# Test Loss :0.3353620767593384, Test Acc: 89.1300048828125
# Best Acc : 89.1300048828125
#
# Epoch : 37/300, Learning Rate : 0.0074474504217505455
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.09199445, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.11it/s, test_loss_batch=tf.Tensor(0.82870036, shape=(), dtype=float32)]
# Train Loss : 0.2781231999397278, Train Acc : 90.23400115966797
# Test Loss :0.3541075587272644, Test Acc: 89.02999877929688
# Best Acc : 89.1300048828125
#
# Epoch : 38/300, Learning Rate : 0.007446001749485731
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.74it/s, train_loss_batch=tf.Tensor(0.16817334, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.95it/s, test_loss_batch=tf.Tensor(0.43905306, shape=(), dtype=float32)]
# Train Loss : 0.2778850495815277, Train Acc : 90.16400146484375
# Test Loss :0.33093804121017456, Test Acc: 89.31999969482422
# Best Acc : 89.31999969482422
#
# Epoch : 39/300, Learning Rate : 0.007444553077220917
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.78it/s, train_loss_batch=tf.Tensor(0.10907161, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.19it/s, test_loss_batch=tf.Tensor(0.6249313, shape=(), dtype=float32)]
# Train Loss : 0.2713874876499176, Train Acc : 90.36800384521484
# Test Loss :0.3333595097064972, Test Acc: 89.30000305175781
# Best Acc : 89.31999969482422
#
# Epoch : 40/300, Learning Rate : 0.007443104404956102
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.13088435, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.24it/s, test_loss_batch=tf.Tensor(0.65320575, shape=(), dtype=float32)]
# Train Loss : 0.26472246646881104, Train Acc : 90.64599609375
# Test Loss :0.3436923325061798, Test Acc: 89.08000183105469
# Best Acc : 89.31999969482422
#
# Epoch : 41/300, Learning Rate : 0.00744165712967515
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.075827755, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.18it/s, test_loss_batch=tf.Tensor(0.51728106, shape=(), dtype=float32)]
# Train Loss : 0.26082655787467957, Train Acc : 90.83799743652344
# Test Loss :0.32841363549232483, Test Acc: 89.5
# Best Acc : 89.5
#
# Epoch : 42/300, Learning Rate : 0.007440210320055485
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.1709263, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.96it/s, test_loss_batch=tf.Tensor(0.39708102, shape=(), dtype=float32)]
# Train Loss : 0.25410881638526917, Train Acc : 91.13999938964844
# Test Loss :0.3277907967567444, Test Acc: 89.11000061035156
# Best Acc : 89.5
#
# Epoch : 43/300, Learning Rate : 0.007438763976097107
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.14293353, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.49it/s, test_loss_batch=tf.Tensor(0.61971337, shape=(), dtype=float32)]
# Train Loss : 0.2549401819705963, Train Acc : 90.947998046875
# Test Loss :0.3274542987346649, Test Acc: 89.47000122070312
# Best Acc : 89.5
#
# Epoch : 44/300, Learning Rate : 0.007437318097800016
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.17557211, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.51it/s, test_loss_batch=tf.Tensor(0.53623706, shape=(), dtype=float32)]
# Train Loss : 0.24618273973464966, Train Acc : 91.27999877929688
# Test Loss :0.3317236304283142, Test Acc: 89.08000183105469
# Best Acc : 89.5
#
# Epoch : 45/300, Learning Rate : 0.0074358731508255005
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.077424526, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.48it/s, test_loss_batch=tf.Tensor(0.34225875, shape=(), dtype=float32)]
# Train Loss : 0.2436235249042511, Train Acc : 91.28999328613281
# Test Loss :0.31606215238571167, Test Acc: 89.88999938964844
# Best Acc : 89.88999938964844
#
# Epoch : 46/300, Learning Rate : 0.007434427738189697
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.89it/s, train_loss_batch=tf.Tensor(0.124401584, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.24it/s, test_loss_batch=tf.Tensor(0.5852887, shape=(), dtype=float32)]
# Train Loss : 0.23837865889072418, Train Acc : 91.54199981689453
# Test Loss :0.33456915616989136, Test Acc: 89.4000015258789
# Best Acc : 89.88999938964844
#
# Epoch : 47/300, Learning Rate : 0.007432983722537756
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.60it/s, train_loss_batch=tf.Tensor(0.12977391, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.34it/s, test_loss_batch=tf.Tensor(0.9261528, shape=(), dtype=float32)]
# Train Loss : 0.2334674745798111, Train Acc : 91.77999877929688
# Test Loss :0.34120646119117737, Test Acc: 89.59000396728516
# Best Acc : 89.88999938964844
#
# Epoch : 48/300, Learning Rate : 0.007431540172547102
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.09338288, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.43it/s, test_loss_batch=tf.Tensor(0.9518504, shape=(), dtype=float32)]
# Train Loss : 0.23351171612739563, Train Acc : 91.75800323486328
# Test Loss :0.343580961227417, Test Acc: 89.54000091552734
# Best Acc : 89.88999938964844
#
# Epoch : 49/300, Learning Rate : 0.007430097553879023
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.86it/s, train_loss_batch=tf.Tensor(0.13346255, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.12it/s, test_loss_batch=tf.Tensor(0.826846, shape=(), dtype=float32)]
# Train Loss : 0.22793732583522797, Train Acc : 91.97000122070312
# Test Loss :0.3319159150123596, Test Acc: 89.49000549316406
# Best Acc : 89.88999938964844
#
# Epoch : 50/300, Learning Rate : 0.0074286554008722305
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.86it/s, train_loss_batch=tf.Tensor(0.07333566, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.12it/s, test_loss_batch=tf.Tensor(0.6589004, shape=(), dtype=float32)]
# Train Loss : 0.22578689455986023, Train Acc : 91.99600219726562
# Test Loss :0.33544793725013733, Test Acc: 89.45999908447266
# Best Acc : 89.88999938964844
#
# Epoch : 51/300, Learning Rate : 0.0074272132478654385
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.19542713, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.87it/s, test_loss_batch=tf.Tensor(0.7228884, shape=(), dtype=float32)]
# Train Loss : 0.2245834320783615, Train Acc : 92.06399536132812
# Test Loss :0.34044232964515686, Test Acc: 89.54000091552734
# Best Acc : 89.88999938964844
#
# Epoch : 52/300, Learning Rate : 0.007425771560519934
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.73it/s, train_loss_batch=tf.Tensor(0.11169753, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.15it/s, test_loss_batch=tf.Tensor(0.81116503, shape=(), dtype=float32)]
# Train Loss : 0.2152135968208313, Train Acc : 92.31399536132812
# Test Loss :0.34037429094314575, Test Acc: 89.49000549316406
# Best Acc : 89.88999938964844
#
# Epoch : 53/300, Learning Rate : 0.0074243308044970036
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.77it/s, train_loss_batch=tf.Tensor(0.12829792, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.10it/s, test_loss_batch=tf.Tensor(0.7282053, shape=(), dtype=float32)]
# Train Loss : 0.211857408285141, Train Acc : 92.39199829101562
# Test Loss :0.33183446526527405, Test Acc: 89.9000015258789
# Best Acc : 89.9000015258789
#
# Epoch : 54/300, Learning Rate : 0.007422890514135361
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.09081636, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.22it/s, test_loss_batch=tf.Tensor(0.5651382, shape=(), dtype=float32)]
# Train Loss : 0.2093297839164734, Train Acc : 92.73399353027344
# Test Loss :0.33504584431648254, Test Acc: 89.69000244140625
# Best Acc : 89.9000015258789
#
# Epoch : 55/300, Learning Rate : 0.0074214511550962925
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.18531995, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.50it/s, test_loss_batch=tf.Tensor(0.5603349, shape=(), dtype=float32)]
# Train Loss : 0.20573864877223969, Train Acc : 92.75800323486328
# Test Loss :0.33237382769584656, Test Acc: 90.02000427246094
# Best Acc : 90.02000427246094
#
# Epoch : 56/300, Learning Rate : 0.007420012261718512
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.10211953, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.71it/s, test_loss_batch=tf.Tensor(0.89907116, shape=(), dtype=float32)]
# Train Loss : 0.20580343902111053, Train Acc : 92.72599792480469
# Test Loss :0.33882462978363037, Test Acc: 89.67000579833984
# Best Acc : 90.02000427246094
#
# Epoch : 57/300, Learning Rate : 0.007418573834002018
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.65it/s, train_loss_batch=tf.Tensor(0.11082591, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.10it/s, test_loss_batch=tf.Tensor(0.92973, shape=(), dtype=float32)]
# Train Loss : 0.20083168148994446, Train Acc : 92.93000030517578
# Test Loss :0.33908146619796753, Test Acc: 90.08000183105469
# Best Acc : 90.08000183105469
#
# Epoch : 58/300, Learning Rate : 0.007417135406285524
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.59it/s, train_loss_batch=tf.Tensor(0.08912126, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.96it/s, test_loss_batch=tf.Tensor(0.8773504, shape=(), dtype=float32)]
# Train Loss : 0.20185723900794983, Train Acc : 92.83599853515625
# Test Loss :0.33571794629096985, Test Acc: 89.94000244140625
# Best Acc : 90.08000183105469
#
# Epoch : 59/300, Learning Rate : 0.007415697909891605
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.69it/s, train_loss_batch=tf.Tensor(0.11594472, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.20it/s, test_loss_batch=tf.Tensor(0.79020673, shape=(), dtype=float32)]
# Train Loss : 0.19245746731758118, Train Acc : 93.15799713134766
# Test Loss :0.33454790711402893, Test Acc: 90.08000183105469
# Best Acc : 90.08000183105469
#
# Epoch : 60/300, Learning Rate : 0.007414261344820261
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.98it/s, train_loss_batch=tf.Tensor(0.06432994, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.10it/s, test_loss_batch=tf.Tensor(0.74678814, shape=(), dtype=float32)]
# Train Loss : 0.1916237324476242, Train Acc : 93.1520004272461
# Test Loss :0.33579570055007935, Test Acc: 89.8800048828125
# Best Acc : 90.08000183105469
#
# Epoch : 61/300, Learning Rate : 0.005559619050472975
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.89it/s, train_loss_batch=tf.Tensor(0.053543746, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.37it/s, test_loss_batch=tf.Tensor(0.9471559, shape=(), dtype=float32)]
# Train Loss : 0.17567972838878632, Train Acc : 93.77400207519531
# Test Loss :0.3410290777683258, Test Acc: 90.10000610351562
# Best Acc : 90.10000610351562
#
# Epoch : 62/300, Learning Rate : 0.005558542441576719
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.86it/s, train_loss_batch=tf.Tensor(0.16941574, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.03it/s, test_loss_batch=tf.Tensor(0.88965344, shape=(), dtype=float32)]
# Train Loss : 0.1676507443189621, Train Acc : 94.04600524902344
# Test Loss :0.3420436680316925, Test Acc: 90.19000244140625
# Best Acc : 90.19000244140625
#
# Epoch : 63/300, Learning Rate : 0.005557466298341751
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.077802315, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 51.92it/s, test_loss_batch=tf.Tensor(1.0000806, shape=(), dtype=float32)]
# Train Loss : 0.16221854090690613, Train Acc : 94.16000366210938
# Test Loss :0.3436970114707947, Test Acc: 90.2300033569336
# Best Acc : 90.2300033569336
#
# Epoch : 64/300, Learning Rate : 0.005556389689445496
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.67it/s, train_loss_batch=tf.Tensor(0.04527349, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.33it/s, test_loss_batch=tf.Tensor(0.7595556, shape=(), dtype=float32)]
# Train Loss : 0.1585848331451416, Train Acc : 94.2979965209961
# Test Loss :0.3328414261341095, Test Acc: 90.43000030517578
# Best Acc : 90.43000030517578
#
# Epoch : 65/300, Learning Rate : 0.005555314011871815
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.06058966, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.03it/s, test_loss_batch=tf.Tensor(0.71851933, shape=(), dtype=float32)]
# Train Loss : 0.16100509464740753, Train Acc : 94.19400024414062
# Test Loss :0.3416059911251068, Test Acc: 90.13999938964844
# Best Acc : 90.43000030517578
#
# Epoch : 66/300, Learning Rate : 0.0055542392656207085
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.78it/s, train_loss_batch=tf.Tensor(0.037299037, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.07it/s, test_loss_batch=tf.Tensor(0.76778686, shape=(), dtype=float32)]
# Train Loss : 0.15907932817935944, Train Acc : 94.39600372314453
# Test Loss :0.3321671485900879, Test Acc: 90.41999816894531
# Best Acc : 90.43000030517578
#
# Epoch : 67/300, Learning Rate : 0.005553164519369602
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.07231607, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.29it/s, test_loss_batch=tf.Tensor(0.843707, shape=(), dtype=float32)]
# Train Loss : 0.15575586259365082, Train Acc : 94.5260009765625
# Test Loss :0.3369888663291931, Test Acc: 90.41000366210938
# Best Acc : 90.43000030517578
#
# Epoch : 68/300, Learning Rate : 0.005552090238779783
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.07425907, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.08it/s, test_loss_batch=tf.Tensor(0.5639113, shape=(), dtype=float32)]
# Train Loss : 0.15546372532844543, Train Acc : 94.50199890136719
# Test Loss :0.3399204909801483, Test Acc: 90.30000305175781
# Best Acc : 90.43000030517578
#
# Epoch : 69/300, Learning Rate : 0.005551016423851252
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.03640325, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.26it/s, test_loss_batch=tf.Tensor(0.48563263, shape=(), dtype=float32)]
# Train Loss : 0.15052743256092072, Train Acc : 94.62000274658203
# Test Loss :0.33319541811943054, Test Acc: 90.29000091552734
# Best Acc : 90.43000030517578
#
# Epoch : 70/300, Learning Rate : 0.00554994260892272
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.11319506, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.33it/s, test_loss_batch=tf.Tensor(0.8566095, shape=(), dtype=float32)]
# Train Loss : 0.14971555769443512, Train Acc : 94.69599914550781
# Test Loss :0.34439292550086975, Test Acc: 90.34000396728516
# Best Acc : 90.43000030517578
#
# Epoch : 71/300, Learning Rate : 0.005548869725316763
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.11024892, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.28it/s, test_loss_batch=tf.Tensor(0.8754736, shape=(), dtype=float32)]
# Train Loss : 0.14588770270347595, Train Acc : 94.87799835205078
# Test Loss :0.3348349928855896, Test Acc: 90.86000061035156
# Best Acc : 90.86000061035156
#
# Epoch : 72/300, Learning Rate : 0.005547796841710806
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.037417248, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.72it/s, test_loss_batch=tf.Tensor(1.0157946, shape=(), dtype=float32)]
# Train Loss : 0.14412757754325867, Train Acc : 94.94000244140625
# Test Loss :0.35005903244018555, Test Acc: 90.58999633789062
# Best Acc : 90.86000061035156
#
# Epoch : 73/300, Learning Rate : 0.0055467248894274235
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.060525846, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.06it/s, test_loss_batch=tf.Tensor(0.6701695, shape=(), dtype=float32)]
# Train Loss : 0.14386402070522308, Train Acc : 94.906005859375
# Test Loss :0.3327733278274536, Test Acc: 90.5999984741211
# Best Acc : 90.86000061035156
#
# Epoch : 74/300, Learning Rate : 0.005545652937144041
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.86it/s, train_loss_batch=tf.Tensor(0.08353154, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.95it/s, test_loss_batch=tf.Tensor(0.89224845, shape=(), dtype=float32)]
# Train Loss : 0.13899433612823486, Train Acc : 95.06800079345703
# Test Loss :0.34449151158332825, Test Acc: 90.8499984741211
# Best Acc : 90.86000061035156
#
# Epoch : 75/300, Learning Rate : 0.005544581916183233
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.86it/s, train_loss_batch=tf.Tensor(0.06351789, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.34it/s, test_loss_batch=tf.Tensor(0.98653173, shape=(), dtype=float32)]
# Train Loss : 0.1415790617465973, Train Acc : 95.03600311279297
# Test Loss :0.354086309671402, Test Acc: 90.44000244140625
# Best Acc : 90.86000061035156
#
# Epoch : 76/300, Learning Rate : 0.005543510429561138
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.77it/s, train_loss_batch=tf.Tensor(0.08217339, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.83it/s, test_loss_batch=tf.Tensor(0.7870836, shape=(), dtype=float32)]
# Train Loss : 0.14310762286186218, Train Acc : 94.88600158691406
# Test Loss :0.33506447076797485, Test Acc: 90.52999877929688
# Best Acc : 90.86000061035156
#
# Epoch : 77/300, Learning Rate : 0.005542439874261618
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.04044468, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.08it/s, test_loss_batch=tf.Tensor(0.7343662, shape=(), dtype=float32)]
# Train Loss : 0.1412544846534729, Train Acc : 95.18399810791016
# Test Loss :0.3332155644893646, Test Acc: 90.69000244140625
# Best Acc : 90.86000061035156
#
# Epoch : 78/300, Learning Rate : 0.0055413697846233845
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.77it/s, train_loss_batch=tf.Tensor(0.04307809, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.23it/s, test_loss_batch=tf.Tensor(0.60478324, shape=(), dtype=float32)]
# Train Loss : 0.13568882644176483, Train Acc : 95.17400360107422
# Test Loss :0.3347648084163666, Test Acc: 90.55999755859375
# Best Acc : 90.86000061035156
#
# Epoch : 79/300, Learning Rate : 0.005540300160646439
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.69it/s, train_loss_batch=tf.Tensor(0.14079472, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.19it/s, test_loss_batch=tf.Tensor(0.7640817, shape=(), dtype=float32)]
# Train Loss : 0.13135401904582977, Train Acc : 95.34400177001953
# Test Loss :0.34460169076919556, Test Acc: 90.55999755859375
# Best Acc : 90.86000061035156
#
# Epoch : 80/300, Learning Rate : 0.00553923100233078
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.90it/s, train_loss_batch=tf.Tensor(0.043708183, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.48it/s, test_loss_batch=tf.Tensor(0.7802701, shape=(), dtype=float32)]
# Train Loss : 0.13166490197181702, Train Acc : 95.4000015258789
# Test Loss :0.3413613438606262, Test Acc: 90.63999938964844
# Best Acc : 90.86000061035156
#
# Epoch : 81/300, Learning Rate : 0.005538162309676409
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.85it/s, train_loss_batch=tf.Tensor(0.048281193, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.50it/s, test_loss_batch=tf.Tensor(0.9407005, shape=(), dtype=float32)]
# Train Loss : 0.13658154010772705, Train Acc : 95.14199829101562
# Test Loss :0.3438992500305176, Test Acc: 90.51000213623047
# Best Acc : 90.86000061035156
#
# Epoch : 82/300, Learning Rate : 0.00553709315136075
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.90it/s, train_loss_batch=tf.Tensor(0.06874292, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.91it/s, test_loss_batch=tf.Tensor(0.89604837, shape=(), dtype=float32)]
# Train Loss : 0.13151895999908447, Train Acc : 95.40399932861328
# Test Loss :0.3384762406349182, Test Acc: 90.63999938964844
# Best Acc : 90.86000061035156
#
# Epoch : 83/300, Learning Rate : 0.005536024924367666
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.03203761, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.38it/s, test_loss_batch=tf.Tensor(0.8411013, shape=(), dtype=float32)]
# Train Loss : 0.12839467823505402, Train Acc : 95.4739990234375
# Test Loss :0.3541811406612396, Test Acc: 90.47000122070312
# Best Acc : 90.86000061035156
#
# Epoch : 84/300, Learning Rate : 0.005534957628697157
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.107327804, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.54it/s, test_loss_batch=tf.Tensor(0.93501127, shape=(), dtype=float32)]
# Train Loss : 0.1277671754360199, Train Acc : 95.46199798583984
# Test Loss :0.3493928611278534, Test Acc: 90.29000091552734
# Best Acc : 90.86000061035156
#
# Epoch : 85/300, Learning Rate : 0.005533890333026648
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.104764804, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.03it/s, test_loss_batch=tf.Tensor(0.8964061, shape=(), dtype=float32)]
# Train Loss : 0.1242755874991417, Train Acc : 95.63800048828125
# Test Loss :0.3495427370071411, Test Acc: 90.41000366210938
# Best Acc : 90.86000061035156
#
# Epoch : 86/300, Learning Rate : 0.0055328235030174255
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.67it/s, train_loss_batch=tf.Tensor(0.14567725, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.31it/s, test_loss_batch=tf.Tensor(0.7127914, shape=(), dtype=float32)]
# Train Loss : 0.12428367137908936, Train Acc : 95.65599822998047
# Test Loss :0.3556565046310425, Test Acc: 89.93000030517578
# Best Acc : 90.86000061035156
#
# Epoch : 87/300, Learning Rate : 0.005531757138669491
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.78it/s, train_loss_batch=tf.Tensor(0.028871264, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.95it/s, test_loss_batch=tf.Tensor(1.1199241, shape=(), dtype=float32)]
# Train Loss : 0.124188132584095, Train Acc : 95.60400390625
# Test Loss :0.3500923216342926, Test Acc: 90.38999938964844
# Best Acc : 90.86000061035156
#
# Epoch : 88/300, Learning Rate : 0.005530690774321556
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.012024467, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.40it/s, test_loss_batch=tf.Tensor(1.1289924, shape=(), dtype=float32)]
# Train Loss : 0.1253214031457901, Train Acc : 95.58399963378906
# Test Loss :0.34483474493026733, Test Acc: 90.61000061035156
# Best Acc : 90.86000061035156
#
# Epoch : 89/300, Learning Rate : 0.005529624875634909
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.78it/s, train_loss_batch=tf.Tensor(0.015430828, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.78it/s, test_loss_batch=tf.Tensor(0.69693595, shape=(), dtype=float32)]
# Train Loss : 0.12064868211746216, Train Acc : 95.69000244140625
# Test Loss :0.3446066975593567, Test Acc: 90.27000427246094
# Best Acc : 90.86000061035156
#
# Epoch : 90/300, Learning Rate : 0.005528559908270836
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.067951724, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.20it/s, test_loss_batch=tf.Tensor(0.7545388, shape=(), dtype=float32)]
# Train Loss : 0.11633236706256866, Train Acc : 95.83599853515625
# Test Loss :0.35177376866340637, Test Acc: 90.66000366210938
# Best Acc : 90.86000061035156
#
# Epoch : 91/300, Learning Rate : 0.004145621322095394
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.85it/s, train_loss_batch=tf.Tensor(0.05448594, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.24it/s, test_loss_batch=tf.Tensor(0.88112414, shape=(), dtype=float32)]
# Train Loss : 0.11184883862733841, Train Acc : 95.9800033569336
# Test Loss :0.34369125962257385, Test Acc: 90.94999694824219
# Best Acc : 90.94999694824219
#
# Epoch : 92/300, Learning Rate : 0.004144823178648949
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.80it/s, train_loss_batch=tf.Tensor(0.017341096, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 30.58it/s, test_loss_batch=tf.Tensor(0.7044767, shape=(), dtype=float32)]
# Train Loss : 0.1044904813170433, Train Acc : 96.302001953125
# Test Loss :0.3442830741405487, Test Acc: 90.70999908447266
# Best Acc : 90.94999694824219
#
# Epoch : 93/300, Learning Rate : 0.0041440255008637905
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.07714413, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.53it/s, test_loss_batch=tf.Tensor(0.7659139, shape=(), dtype=float32)]
# Train Loss : 0.10006007552146912, Train Acc : 96.46199798583984
# Test Loss :0.34587427973747253, Test Acc: 90.97000122070312
# Best Acc : 90.97000122070312
#
# Epoch : 94/300, Learning Rate : 0.004143227357417345
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.027920818, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.52it/s, test_loss_batch=tf.Tensor(0.74296516, shape=(), dtype=float32)]
# Train Loss : 0.1019122526049614, Train Acc : 96.46199798583984
# Test Loss :0.3436172306537628, Test Acc: 90.70999908447266
# Best Acc : 90.97000122070312
#
# Epoch : 95/300, Learning Rate : 0.004142429679632187
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.68it/s, train_loss_batch=tf.Tensor(0.031677626, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.19it/s, test_loss_batch=tf.Tensor(0.80120856, shape=(), dtype=float32)]
# Train Loss : 0.09759213030338287, Train Acc : 96.56400299072266
# Test Loss :0.34588032960891724, Test Acc: 90.69999694824219
# Best Acc : 90.97000122070312
#
# Epoch : 96/300, Learning Rate : 0.004141632933169603
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.025020713, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.17it/s, test_loss_batch=tf.Tensor(0.9425382, shape=(), dtype=float32)]
# Train Loss : 0.09366721659898758, Train Acc : 96.73200225830078
# Test Loss :0.3591481149196625, Test Acc: 90.8699951171875
# Best Acc : 90.97000122070312
#
# Epoch : 97/300, Learning Rate : 0.00414083618670702
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.88it/s, train_loss_batch=tf.Tensor(0.03493787, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.94it/s, test_loss_batch=tf.Tensor(0.8551285, shape=(), dtype=float32)]
# Train Loss : 0.09599466621875763, Train Acc : 96.58799743652344
# Test Loss :0.35792797803878784, Test Acc: 90.7699966430664
# Best Acc : 90.97000122070312
#
# Epoch : 98/300, Learning Rate : 0.004140039905905724
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.82it/s, train_loss_batch=tf.Tensor(0.039366473, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.53it/s, test_loss_batch=tf.Tensor(0.7047579, shape=(), dtype=float32)]
# Train Loss : 0.09459015727043152, Train Acc : 96.69599914550781
# Test Loss :0.3450280725955963, Test Acc: 91.11000061035156
# Best Acc : 91.11000061035156
#
# Epoch : 99/300, Learning Rate : 0.004139243625104427
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.015687631, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.25it/s, test_loss_batch=tf.Tensor(0.9195039, shape=(), dtype=float32)]
# Train Loss : 0.09320951253175735, Train Acc : 96.66999816894531
# Test Loss :0.3641171455383301, Test Acc: 90.76000213623047
# Best Acc : 91.11000061035156
#
# Epoch : 100/300, Learning Rate : 0.004138447344303131
# TRAINING...
# ...
# Testing...
# 100% 40/40 [00:00<00:00, 53.07it/s, test_loss_batch=tf.Tensor(1.5068434, shape=(), dtype=float32)]
# Train Loss : 0.023433035239577293, Train Acc : 99.18199920654297
# Test Loss :0.43643227219581604, Test Acc: 91.50999450683594
# Best Acc : 91.80999755859375
#
# Epoch : 265/300, Learning Rate : 0.0009518753504380584
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.88it/s, train_loss_batch=tf.Tensor(0.0001949933, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.84it/s, test_loss_batch=tf.Tensor(1.3928906, shape=(), dtype=float32)]
# Train Loss : 0.022056546062231064, Train Acc : 99.22799682617188
# Test Loss :0.43840259313583374, Test Acc: 91.44999694824219
# Best Acc : 91.80999755859375
#
# Epoch : 266/300, Learning Rate : 0.000951697991695255
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.68it/s, train_loss_batch=tf.Tensor(0.0012777082, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.95it/s, test_loss_batch=tf.Tensor(1.2334296, shape=(), dtype=float32)]
# Train Loss : 0.02254466898739338, Train Acc : 99.18000030517578
# Test Loss :0.4361812472343445, Test Acc: 91.5199966430664
# Best Acc : 91.80999755859375
#
# Epoch : 267/300, Learning Rate : 0.0009515207493677735
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.0004353303, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.71it/s, test_loss_batch=tf.Tensor(1.3301512, shape=(), dtype=float32)]
# Train Loss : 0.023633791133761406, Train Acc : 99.17200469970703
# Test Loss :0.4407755732536316, Test Acc: 91.3699951171875
# Best Acc : 91.80999755859375
#
# Epoch : 268/300, Learning Rate : 0.0009513433906249702
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.002664734, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.86it/s, test_loss_batch=tf.Tensor(1.5828682, shape=(), dtype=float32)]
# Train Loss : 0.020073113963007927, Train Acc : 99.25399780273438
# Test Loss :0.4452034533023834, Test Acc: 91.43000030517578
# Best Acc : 91.80999755859375
#
# Epoch : 269/300, Learning Rate : 0.0009511662647128105
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.72it/s, train_loss_batch=tf.Tensor(0.0023336448, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.03it/s, test_loss_batch=tf.Tensor(1.436932, shape=(), dtype=float32)]
# Train Loss : 0.02328053116798401, Train Acc : 99.22200012207031
# Test Loss :0.44667378067970276, Test Acc: 91.45999908447266
# Best Acc : 91.80999755859375
#
# Epoch : 270/300, Learning Rate : 0.0009509891970083117
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.82it/s, train_loss_batch=tf.Tensor(0.045341503, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.75it/s, test_loss_batch=tf.Tensor(1.5951303, shape=(), dtype=float32)]
# Train Loss : 0.023015663027763367, Train Acc : 99.20999908447266
# Test Loss :0.43947452306747437, Test Acc: 91.52999877929688
# Best Acc : 91.80999755859375
#
# Epoch : 271/300, Learning Rate : 0.0007131091551855206
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.00023342855, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.97it/s, test_loss_batch=tf.Tensor(1.4440093, shape=(), dtype=float32)]
# Train Loss : 0.021648377180099487, Train Acc : 99.26000213623047
# Test Loss :0.436458021402359, Test Acc: 91.75
# Best Acc : 91.80999755859375
#
# Epoch : 272/300, Learning Rate : 0.0007129764417186379
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.024162184, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.14it/s, test_loss_batch=tf.Tensor(1.5389001, shape=(), dtype=float32)]
# Train Loss : 0.02092692255973816, Train Acc : 99.28399658203125
# Test Loss :0.43640390038490295, Test Acc: 91.72999572753906
# Best Acc : 91.80999755859375
#
# Epoch : 273/300, Learning Rate : 0.0007128437864594162
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.68it/s, train_loss_batch=tf.Tensor(0.0023391347, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.29it/s, test_loss_batch=tf.Tensor(1.5279127, shape=(), dtype=float32)]
# Train Loss : 0.020608680322766304, Train Acc : 99.28800201416016
# Test Loss :0.4402419626712799, Test Acc: 91.72000122070312
# Best Acc : 91.80999755859375
#
# Epoch : 274/300, Learning Rate : 0.0007127110729925334
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.0051229736, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.04it/s, test_loss_batch=tf.Tensor(1.5698277, shape=(), dtype=float32)]
# Train Loss : 0.02006162516772747, Train Acc : 99.31200408935547
# Test Loss :0.4369603991508484, Test Acc: 91.79000091552734
# Best Acc : 91.80999755859375
#
# Epoch : 275/300, Learning Rate : 0.0007125785341486335
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.00086314295, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.30it/s, test_loss_batch=tf.Tensor(1.5466022, shape=(), dtype=float32)]
# Train Loss : 0.0207656379789114, Train Acc : 99.31600189208984
# Test Loss :0.43759918212890625, Test Acc: 91.77999877929688
# Best Acc : 91.80999755859375
#
# Epoch : 276/300, Learning Rate : 0.0007124460535123944
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.84it/s, train_loss_batch=tf.Tensor(0.0006274411, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.35it/s, test_loss_batch=tf.Tensor(1.4210129, shape=(), dtype=float32)]
# Train Loss : 0.022344445809721947, Train Acc : 99.23200225830078
# Test Loss :0.4336525797843933, Test Acc: 91.65999603271484
# Best Acc : 91.80999755859375
#
# Epoch : 277/300, Learning Rate : 0.0007123135728761554
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.0004906503, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.39it/s, test_loss_batch=tf.Tensor(1.5092303, shape=(), dtype=float32)]
# Train Loss : 0.021491747349500656, Train Acc : 99.26200103759766
# Test Loss :0.4444596767425537, Test Acc: 91.58999633789062
# Best Acc : 91.80999755859375
#
# Epoch : 278/300, Learning Rate : 0.0007121811504475772
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.00052730856, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.12it/s, test_loss_batch=tf.Tensor(1.4873732, shape=(), dtype=float32)]
# Train Loss : 0.02034224383533001, Train Acc : 99.2699966430664
# Test Loss :0.43662580847740173, Test Acc: 91.75
# Best Acc : 91.80999755859375
#
# Epoch : 279/300, Learning Rate : 0.00071204878622666
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.89it/s, train_loss_batch=tf.Tensor(0.00044576303, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.05it/s, test_loss_batch=tf.Tensor(1.4430207, shape=(), dtype=float32)]
# Train Loss : 0.021666500717401505, Train Acc : 99.2820053100586
# Test Loss :0.4351533353328705, Test Acc: 91.57999420166016
# Best Acc : 91.80999755859375
#
# Epoch : 280/300, Learning Rate : 0.0007119164220057428
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.79it/s, train_loss_batch=tf.Tensor(0.0013164921, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.29it/s, test_loss_batch=tf.Tensor(1.4196761, shape=(), dtype=float32)]
# Train Loss : 0.02018979750573635, Train Acc : 99.30999755859375
# Test Loss :0.44324517250061035, Test Acc: 91.66999816894531
# Best Acc : 91.80999755859375
#
# Epoch : 281/300, Learning Rate : 0.0007117841159924865
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.0011934981, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.49it/s, test_loss_batch=tf.Tensor(1.3807743, shape=(), dtype=float32)]
# Train Loss : 0.021252788603305817, Train Acc : 99.28399658203125
# Test Loss :0.43900594115257263, Test Acc: 91.62999725341797
# Best Acc : 91.80999755859375
#
# Epoch : 282/300, Learning Rate : 0.000711651926394552
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.85it/s, train_loss_batch=tf.Tensor(0.00055450486, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.06it/s, test_loss_batch=tf.Tensor(1.4071751, shape=(), dtype=float32)]
# Train Loss : 0.017678411677479744, Train Acc : 99.39200592041016
# Test Loss :0.43793100118637085, Test Acc: 91.5999984741211
# Best Acc : 91.80999755859375
#
# Epoch : 283/300, Learning Rate : 0.0007115197367966175
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.70it/s, train_loss_batch=tf.Tensor(0.039333444, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.19it/s, test_loss_batch=tf.Tensor(1.467754, shape=(), dtype=float32)]
# Train Loss : 0.0216197669506073, Train Acc : 99.23799896240234
# Test Loss :0.4395189881324768, Test Acc: 91.7699966430664
# Best Acc : 91.80999755859375
#
# Epoch : 284/300, Learning Rate : 0.0007113876636140049
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.0034507483, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.92it/s, test_loss_batch=tf.Tensor(1.5717479, shape=(), dtype=float32)]
# Train Loss : 0.02008049003779888, Train Acc : 99.33799743652344
# Test Loss :0.45320600271224976, Test Acc: 91.52999877929688
# Best Acc : 91.80999755859375
#
# Epoch : 285/300, Learning Rate : 0.0007112555904313922
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.76it/s, train_loss_batch=tf.Tensor(0.0013999752, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.38it/s, test_loss_batch=tf.Tensor(1.6081465, shape=(), dtype=float32)]
# Train Loss : 0.02014627307653427, Train Acc : 99.31600189208984
# Test Loss :0.44204598665237427, Test Acc: 91.6199951171875
# Best Acc : 91.80999755859375
#
# Epoch : 286/300, Learning Rate : 0.0007111234590411186
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.81it/s, train_loss_batch=tf.Tensor(0.011281886, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.28it/s, test_loss_batch=tf.Tensor(1.5825399, shape=(), dtype=float32)]
# Train Loss : 0.019234083592891693, Train Acc : 99.36199951171875
# Test Loss :0.4422703683376312, Test Acc: 91.73999786376953
# Best Acc : 91.80999755859375
#
# Epoch : 287/300, Learning Rate : 0.0007109915022738278
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.83it/s, train_loss_batch=tf.Tensor(0.001499065, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.92it/s, test_loss_batch=tf.Tensor(1.4752342, shape=(), dtype=float32)]
# Train Loss : 0.019872421398758888, Train Acc : 99.30400085449219
# Test Loss :0.44350752234458923, Test Acc: 91.72999572753906
# Best Acc : 91.80999755859375
#
# Epoch : 288/300, Learning Rate : 0.0007108596037141979
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.75it/s, train_loss_batch=tf.Tensor(0.0066559226, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.98it/s, test_loss_batch=tf.Tensor(1.5379641, shape=(), dtype=float32)]
# Train Loss : 0.02042137086391449, Train Acc : 99.24200439453125
# Test Loss :0.4447154998779297, Test Acc: 91.65999603271484
# Best Acc : 91.80999755859375
#
# Epoch : 289/300, Learning Rate : 0.000710727705154568
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.85it/s, train_loss_batch=tf.Tensor(0.002488357, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.26it/s, test_loss_batch=tf.Tensor(1.5781206, shape=(), dtype=float32)]
# Train Loss : 0.020354392006993294, Train Acc : 99.31600189208984
# Test Loss :0.4500979781150818, Test Acc: 91.55999755859375
# Best Acc : 91.80999755859375
#
# Epoch : 290/300, Learning Rate : 0.0007105959230102599
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.60it/s, train_loss_batch=tf.Tensor(0.0018713765, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.23it/s, test_loss_batch=tf.Tensor(1.57377, shape=(), dtype=float32)]
# Train Loss : 0.020557619631290436, Train Acc : 99.31800079345703
# Test Loss :0.4445562958717346, Test Acc: 91.68000030517578
# Best Acc : 91.80999755859375
#
# Epoch : 291/300, Learning Rate : 0.0007104641408659518
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.00055049045, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.34it/s, test_loss_batch=tf.Tensor(1.5812505, shape=(), dtype=float32)]
# Train Loss : 0.01932385563850403, Train Acc : 99.36000061035156
# Test Loss :0.4476437568664551, Test Acc: 91.55999755859375
# Best Acc : 91.80999755859375
#
# Epoch : 292/300, Learning Rate : 0.0007103323005139828
# TRAINING...
# 100% 196/196 [00:10<00:00, 17.91it/s, train_loss_batch=tf.Tensor(0.010204131, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.77it/s, test_loss_batch=tf.Tensor(1.6987904, shape=(), dtype=float32)]
# Train Loss : 0.01901749148964882, Train Acc : 99.35600280761719
# Test Loss :0.44950246810913086, Test Acc: 91.52999877929688
# Best Acc : 91.80999755859375
#
# Epoch : 293/300, Learning Rate : 0.0007102006347849965
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.72it/s, train_loss_batch=tf.Tensor(0.005817429, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.09it/s, test_loss_batch=tf.Tensor(1.5365212, shape=(), dtype=float32)]
# Train Loss : 0.02019057609140873, Train Acc : 99.31800079345703
# Test Loss :0.4419235587120056, Test Acc: 91.43999481201172
# Best Acc : 91.80999755859375
#
# Epoch : 294/300, Learning Rate : 0.0007100690272636712
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.78it/s, train_loss_batch=tf.Tensor(0.0013254753, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.39it/s, test_loss_batch=tf.Tensor(1.5710344, shape=(), dtype=float32)]
# Train Loss : 0.020143622532486916, Train Acc : 99.3479995727539
# Test Loss :0.4462493062019348, Test Acc: 91.6199951171875
# Best Acc : 91.80999755859375
#
# Epoch : 295/300, Learning Rate : 0.0007099374197423458
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.71it/s, train_loss_batch=tf.Tensor(0.00017229051, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.12it/s, test_loss_batch=tf.Tensor(1.5591246, shape=(), dtype=float32)]
# Train Loss : 0.02041223831474781, Train Acc : 99.2820053100586
# Test Loss :0.4457930624485016, Test Acc: 91.54000091552734
# Best Acc : 91.80999755859375
#
# Epoch : 296/300, Learning Rate : 0.0007098059286363423
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.56it/s, train_loss_batch=tf.Tensor(0.029650638, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.66it/s, test_loss_batch=tf.Tensor(1.5293082, shape=(), dtype=float32)]
# Train Loss : 0.01938246190547943, Train Acc : 99.33599853515625
# Test Loss :0.4489724636077881, Test Acc: 91.56999969482422
# Best Acc : 91.80999755859375
#
# Epoch : 297/300, Learning Rate : 0.0007096744375303388
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.59it/s, train_loss_batch=tf.Tensor(0.0035436265, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.86it/s, test_loss_batch=tf.Tensor(1.5938061, shape=(), dtype=float32)]
# Train Loss : 0.018111247569322586, Train Acc : 99.38800048828125
# Test Loss :0.4544247090816498, Test Acc: 91.56999969482422
# Best Acc : 91.80999755859375
#
# Epoch : 298/300, Learning Rate : 0.0007095429464243352
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.72it/s, train_loss_batch=tf.Tensor(0.00037017892, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 53.00it/s, test_loss_batch=tf.Tensor(1.3977731, shape=(), dtype=float32)]
# Train Loss : 0.017791932448744774, Train Acc : 99.40599822998047
# Test Loss :0.4471466541290283, Test Acc: 91.52999877929688
# Best Acc : 91.80999755859375
#
# Epoch : 299/300, Learning Rate : 0.0007094115717336535
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.64it/s, train_loss_batch=tf.Tensor(0.0007498322, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.68it/s, test_loss_batch=tf.Tensor(1.4261869, shape=(), dtype=float32)]
# Train Loss : 0.01986694522202015, Train Acc : 99.3499984741211
# Test Loss :0.45035654306411743, Test Acc: 91.54000091552734
# Best Acc : 91.80999755859375
#
# Epoch : 300/300, Learning Rate : 0.0007092801970429718
# TRAINING...
# 100% 196/196 [00:11<00:00, 17.74it/s, train_loss_batch=tf.Tensor(0.00068650674, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 52.91it/s, test_loss_batch=tf.Tensor(1.5351555, shape=(), dtype=float32)]
# Train Loss : 0.018518531695008278, Train Acc : 99.3280029296875
# Test Loss :0.4500604271888733, Test Acc: 91.79999542236328
# Best Acc : 91.80999755859375

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.datasets import cifar10
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from get_model import get_model


# def normalization(train_images, test_images):
#     mean = np.mean(train_images, axis=(0, 1, 2, 3))
#     std = np.std(train_images, axis=(0, 1, 2, 3))
#     train_images = (train_images - mean) / (std + 1e-7)
#     test_images = (test_images - mean) / (std + 1e-7)
#     return train_images, test_images


# def load_images():
#     (train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

#     train_images = train_images.astype(np.float32)
#     test_images = test_images.astype(np.float32)

#     (train_images, test_images) = normalization(train_images, test_images)

#     train_labels = to_categorical(train_labels, 10)
#     test_labels = to_categorical(test_labels, 10)

#     # train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).shuffle(
#     #     buffer_size=10000).batch(batch_size)
#     # test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

#     return train_images, train_labels, test_images, test_labels
# if __name__ == '__main__':
#     print(tf.__version__)
#     print(keras.__version__)

#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#         # 텐서플로가 첫 번째 GPU만 사용하도록 제한
#         try:
#             print('start with GPU 7')
#             tf.config.experimental.set_visible_devices(gpus[7], 'GPU')
#             tf.config.experimental.set_memory_growth(gpus[7], True)
#         except RuntimeError as e:
#             # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
#             print(e)

#     training_epochs = 250
#     batch_size = 128
#     learning_rate = 0.1
#     momentum = 0.9
#     lr_decay = 1e-6
#     lr_drop = 20

#     tf.random.set_seed(777)

#     def lr_scheduler(epoch):
#         return learning_rate * (0.5 ** (epoch // lr_drop))

#     reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

#     train_images, train_labels, test_images, test_labels = load_images()

#     # data augmentation
#     datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip=True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images
#     # (std, mean, and principal components if ZCA whitening is applied).
#     datagen.fit(train_images)

#     model = get_model('vgg11')

#     optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate,
#                                         decay=1e-6, momentum=momentum, nesterov=True)
#     model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

#     model.fit_generator(datagen.flow(train_images, train_labels,
#                                      batch_size=batch_size), epochs=training_epochs, verbose=2, callbacks=[reduce_lr],
#                         steps_per_epoch=train_images.shape[0] // batch_size, validation_data=(test_images, test_labels))

#     model.save_weights('cifar10vgg_custom.h5')
