# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Tensorflow-2.x-Practices/Image Classification on CIFAR10
# Out:
# /content/gdrive/My Drive/Tensorflow-2.x-Practices/Image Classification on CIFAR10

# %%
# !python main.py -m "vgg16" -b 256 -lr 0.01 -e 300
# Out:
# 2021-10-05 17:18:18.803463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:19.104566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:19.105180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.076828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.077423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.077992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.078594: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-10-05 17:18:22.078654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2021-10-05 17:18:22.082251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.082863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.083370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.084175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.084733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.085238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.085803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.086324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-05 17:18:22.086847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Device :  /device:GPU:0
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step
# Training samples :  50000
# Testing samples : 10000
# tcmalloc: large alloc 1228800000 bytes == 0x55fb5dace000 @  0x7f921fb281e7 0x7f921d6a846e 0x7f921d6f8c7b 0x7f921d6f8d18 0x7f921d7b4d79 0x7f921d7b7e4c 0x7f921d8d6e7f 0x7f921d8dcfb5 0x7f921d8dee3d 0x7f921d8e0516 0x55fb39abb720 0x55fb39abb2f9 0x7f921d7bf0db 0x55fb39ba40b2 0x55fb39b2a62d 0x55fb39b289ee 0x55fb39abbbda 0x55fb39b2a737 0x55fb39b289ee 0x55fb399fae2b 0x55fb39b2afe4 0x55fb39b289ee 0x55fb399fae2b 0x7f921d6e5ef7 0x55fb39aba437 0x55fb39aba240 0x55fb39b2d973 0x55fb39b289ee 0x55fb39abbbda 0x55fb39b2a737 0x55fb39b289ee
# tcmalloc: large alloc 1228800000 bytes == 0x55fb5dace000 @  0x7f921fb281e7 0x7f921d6a846e 0x7f921d6f8c7b 0x7f921d6f8d18 0x7f921d7b4d79 0x7f921d7b7e4c 0x7f921d8d6e7f 0x7f921d8dcfb5 0x7f921d8dee3d 0x7f921d8e0516 0x55fb39abb720 0x55fb39abb2f9 0x7f921d7bf0db 0x55fb39ba4113 0x55fb39b2a62d 0x55fb39b289ee 0x55fb39b286f3 0x55fb39bf24c2 0x55fb39bf283d 0x55fb39bf26e6 0x55fb39bca163 0x55fb39bc9e0c 0x7f921e912bf7 0x55fb39bc9cea
# Epoch : 1/300, Learning Rate : 0.009999999776482582
# TRAINING...
#   0% 0/196 [00:00<?, ?it/s]2021-10-05 17:18:39.735508: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-05 17:18:44.094080: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 100% 196/196 [00:34<00:00,  5.74it/s, train_loss_batch=tf.Tensor(1.4876331, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:02<00:00, 19.89it/s, test_loss_batch=tf.Tensor(1.5946419, shape=(), dtype=float32)]
# Train Loss : 1.6279776096343994, Train Acc : 39.84199905395508
# Test Loss :1.272148609161377, Test Acc: 53.90999984741211
# Best Acc : 53.90999984741211
#
# Epoch : 2/300, Learning Rate : 0.009998040273785591
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.40it/s, train_loss_batch=tf.Tensor(1.124411, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.76it/s, test_loss_batch=tf.Tensor(1.363132, shape=(), dtype=float32)]
# Train Loss : 1.2874338626861572, Train Acc : 53.625999450683594
# Test Loss :1.036270022392273, Test Acc: 62.709999084472656
# Best Acc : 62.709999084472656
#
# Epoch : 3/300, Learning Rate : 0.009996081702411175
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.59it/s, train_loss_batch=tf.Tensor(0.94660425, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.56it/s, test_loss_batch=tf.Tensor(1.1821122, shape=(), dtype=float32)]
# Train Loss : 1.1114304065704346, Train Acc : 60.2140007019043
# Test Loss :0.8526012301445007, Test Acc: 70.0999984741211
# Best Acc : 70.0999984741211
#
# Epoch : 4/300, Learning Rate : 0.009994122199714184
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.60it/s, train_loss_batch=tf.Tensor(0.9048036, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 42.95it/s, test_loss_batch=tf.Tensor(1.3623483, shape=(), dtype=float32)]
# Train Loss : 0.9822079539299011, Train Acc : 65.3479995727539
# Test Loss :0.7681987881660461, Test Acc: 73.62999725341797
# Best Acc : 73.62999725341797
#
# Epoch : 5/300, Learning Rate : 0.009992165490984917
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.74402636, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.68it/s, test_loss_batch=tf.Tensor(1.084567, shape=(), dtype=float32)]
# Train Loss : 0.8884450793266296, Train Acc : 68.88800048828125
# Test Loss :0.6944402456283569, Test Acc: 76.34000396728516
# Best Acc : 76.34000396728516
#
# Epoch : 6/300, Learning Rate : 0.00999020878225565
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.7521383, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.36it/s, test_loss_batch=tf.Tensor(0.7505536, shape=(), dtype=float32)]
# Train Loss : 0.8171873092651367, Train Acc : 71.447998046875
# Test Loss :0.6442646384239197, Test Acc: 77.30000305175781
# Best Acc : 77.30000305175781
#
# Epoch : 7/300, Learning Rate : 0.009988253936171532
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.61it/s, train_loss_batch=tf.Tensor(0.6531701, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.72it/s, test_loss_batch=tf.Tensor(0.8925824, shape=(), dtype=float32)]
# Train Loss : 0.7680051326751709, Train Acc : 72.98999786376953
# Test Loss :0.6046543121337891, Test Acc: 79.48999786376953
# Best Acc : 79.48999786376953
#
# Epoch : 8/300, Learning Rate : 0.009986299090087414
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.6217059, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.06it/s, test_loss_batch=tf.Tensor(0.90686977, shape=(), dtype=float32)]
# Train Loss : 0.7133249044418335, Train Acc : 75.05400085449219
# Test Loss :0.5682941675186157, Test Acc: 80.7699966430664
# Best Acc : 80.7699966430664
#
# Epoch : 9/300, Learning Rate : 0.00998434517532587
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.61it/s, train_loss_batch=tf.Tensor(0.5079522, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.78it/s, test_loss_batch=tf.Tensor(1.0968363, shape=(), dtype=float32)]
# Train Loss : 0.6742703914642334, Train Acc : 76.62000274658203
# Test Loss :0.556940495967865, Test Acc: 81.38999938964844
# Best Acc : 81.38999938964844
#
# Epoch : 10/300, Learning Rate : 0.009982390329241753
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.484631, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.15it/s, test_loss_batch=tf.Tensor(0.8559538, shape=(), dtype=float32)]
# Train Loss : 0.6423166394233704, Train Acc : 77.6500015258789
# Test Loss :0.5157966613769531, Test Acc: 82.63999938964844
# Best Acc : 82.63999938964844
#
# Epoch : 11/300, Learning Rate : 0.009980437345802784
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.58it/s, train_loss_batch=tf.Tensor(0.5464605, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.64it/s, test_loss_batch=tf.Tensor(0.89082634, shape=(), dtype=float32)]
# Train Loss : 0.6105040907859802, Train Acc : 78.81400299072266
# Test Loss :0.5035592317581177, Test Acc: 83.1300048828125
# Best Acc : 83.1300048828125
#
# Epoch : 12/300, Learning Rate : 0.009978486225008965
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.38943544, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.51it/s, test_loss_batch=tf.Tensor(0.9357148, shape=(), dtype=float32)]
# Train Loss : 0.579714298248291, Train Acc : 79.8759994506836
# Test Loss :0.49341702461242676, Test Acc: 83.45999908447266
# Best Acc : 83.45999908447266
#
# Epoch : 13/300, Learning Rate : 0.009976535104215145
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.57it/s, train_loss_batch=tf.Tensor(0.41838774, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.16it/s, test_loss_batch=tf.Tensor(0.83279735, shape=(), dtype=float32)]
# Train Loss : 0.5610573291778564, Train Acc : 80.48200225830078
# Test Loss :0.4781523644924164, Test Acc: 84.1300048828125
# Best Acc : 84.1300048828125
#
# Epoch : 14/300, Learning Rate : 0.0099745849147439
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.40838194, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.53it/s, test_loss_batch=tf.Tensor(0.79905325, shape=(), dtype=float32)]
# Train Loss : 0.538068950176239, Train Acc : 81.44400024414062
# Test Loss :0.45924681425094604, Test Acc: 84.75999450683594
# Best Acc : 84.75999450683594
#
# Epoch : 15/300, Learning Rate : 0.00997263565659523
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.44317913, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.75it/s, test_loss_batch=tf.Tensor(0.7487642, shape=(), dtype=float32)]
# Train Loss : 0.5218827724456787, Train Acc : 81.87999725341797
# Test Loss :0.44158491492271423, Test Acc: 85.30999755859375
# Best Acc : 85.30999755859375
#
# Epoch : 16/300, Learning Rate : 0.009970685467123985
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.44638076, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.50it/s, test_loss_batch=tf.Tensor(0.70071477, shape=(), dtype=float32)]
# Train Loss : 0.5008180737495422, Train Acc : 82.72599792480469
# Test Loss :0.4313761591911316, Test Acc: 85.44999694824219
# Best Acc : 85.44999694824219
#
# Epoch : 17/300, Learning Rate : 0.00996873714029789
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.32595557, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.68it/s, test_loss_batch=tf.Tensor(0.68608654, shape=(), dtype=float32)]
# Train Loss : 0.4835525453090668, Train Acc : 83.2979965209961
# Test Loss :0.42642831802368164, Test Acc: 85.45999908447266
# Best Acc : 85.45999908447266
#
# Epoch : 18/300, Learning Rate : 0.009966790676116943
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.28080502, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.48it/s, test_loss_batch=tf.Tensor(0.7565635, shape=(), dtype=float32)]
# Train Loss : 0.4680628776550293, Train Acc : 83.73200225830078
# Test Loss :0.41094356775283813, Test Acc: 86.23999786376953
# Best Acc : 86.23999786376953
#
# Epoch : 19/300, Learning Rate : 0.009964844211935997
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.60it/s, train_loss_batch=tf.Tensor(0.28245726, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.74it/s, test_loss_batch=tf.Tensor(0.69666475, shape=(), dtype=float32)]
# Train Loss : 0.4505215883255005, Train Acc : 84.197998046875
# Test Loss :0.40727242827415466, Test Acc: 86.5
# Best Acc : 86.5
#
# Epoch : 20/300, Learning Rate : 0.00996289774775505
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.22630349, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.55it/s, test_loss_batch=tf.Tensor(1.0576283, shape=(), dtype=float32)]
# Train Loss : 0.4409444332122803, Train Acc : 84.71599578857422
# Test Loss :0.4084767699241638, Test Acc: 86.56999969482422
# Best Acc : 86.56999969482422
#
# Epoch : 21/300, Learning Rate : 0.009960953146219254
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.29668647, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.48it/s, test_loss_batch=tf.Tensor(1.0338296, shape=(), dtype=float32)]
# Train Loss : 0.4289166331291199, Train Acc : 85.06800079345703
# Test Loss :0.40331655740737915, Test Acc: 87.19000244140625
# Best Acc : 87.19000244140625
#
# Epoch : 22/300, Learning Rate : 0.009959007613360882
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.59it/s, train_loss_batch=tf.Tensor(0.25740272, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.16it/s, test_loss_batch=tf.Tensor(1.0396323, shape=(), dtype=float32)]
# Train Loss : 0.41131988167762756, Train Acc : 85.62999725341797
# Test Loss :0.39344221353530884, Test Acc: 87.06999969482422
# Best Acc : 87.19000244140625
#
# Epoch : 23/300, Learning Rate : 0.009957064874470234
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.15152921, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(0.56241435, shape=(), dtype=float32)]
# Train Loss : 0.4042791724205017, Train Acc : 85.83399963378906
# Test Loss :0.3886965215206146, Test Acc: 86.81999969482422
# Best Acc : 87.19000244140625
#
# Epoch : 24/300, Learning Rate : 0.009955122135579586
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.30272564, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.79it/s, test_loss_batch=tf.Tensor(0.9082117, shape=(), dtype=float32)]
# Train Loss : 0.39128705859184265, Train Acc : 86.38200378417969
# Test Loss :0.3902338147163391, Test Acc: 87.20999908447266
# Best Acc : 87.20999908447266
#
# Epoch : 25/300, Learning Rate : 0.009953180328011513
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.61it/s, train_loss_batch=tf.Tensor(0.19448762, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.18it/s, test_loss_batch=tf.Tensor(1.0095022, shape=(), dtype=float32)]
# Train Loss : 0.3776531219482422, Train Acc : 86.63800048828125
# Test Loss :0.38586294651031494, Test Acc: 87.54000091552734
# Best Acc : 87.54000091552734
#
# Epoch : 26/300, Learning Rate : 0.00995123852044344
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.29795256, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.39it/s, test_loss_batch=tf.Tensor(0.6429281, shape=(), dtype=float32)]
# Train Loss : 0.37261301279067993, Train Acc : 87.00799560546875
# Test Loss :0.363476425409317, Test Acc: 87.83000183105469
# Best Acc : 87.83000183105469
#
# Epoch : 27/300, Learning Rate : 0.009949298575520515
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.2816086, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 42.83it/s, test_loss_batch=tf.Tensor(0.7673695, shape=(), dtype=float32)]
# Train Loss : 0.36160025000572205, Train Acc : 87.4520034790039
# Test Loss :0.37757331132888794, Test Acc: 87.70999908447266
# Best Acc : 87.83000183105469
#
# Epoch : 28/300, Learning Rate : 0.009947357699275017
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.21499085, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.48it/s, test_loss_batch=tf.Tensor(0.7426154, shape=(), dtype=float32)]
# Train Loss : 0.35551539063453674, Train Acc : 87.59400177001953
# Test Loss :0.36672908067703247, Test Acc: 87.63999938964844
# Best Acc : 87.83000183105469
#
# Epoch : 29/300, Learning Rate : 0.009945418685674667
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.21096341, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.79it/s, test_loss_batch=tf.Tensor(0.8567282, shape=(), dtype=float32)]
# Train Loss : 0.34400397539138794, Train Acc : 87.98600006103516
# Test Loss :0.363603413105011, Test Acc: 88.18000030517578
# Best Acc : 88.18000030517578
#
# Epoch : 30/300, Learning Rate : 0.009943480603396893
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.19119093, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.38it/s, test_loss_batch=tf.Tensor(0.78451866, shape=(), dtype=float32)]
# Train Loss : 0.3323514759540558, Train Acc : 88.45600128173828
# Test Loss :0.3649287819862366, Test Acc: 88.0
# Best Acc : 88.18000030517578
#
# Epoch : 31/300, Learning Rate : 0.007456157822161913
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.73it/s, train_loss_batch=tf.Tensor(0.21642561, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.09it/s, test_loss_batch=tf.Tensor(0.8064561, shape=(), dtype=float32)]
# Train Loss : 0.30634063482284546, Train Acc : 89.32600402832031
# Test Loss :0.3505190312862396, Test Acc: 88.47000122070312
# Best Acc : 88.47000122070312
#
# Epoch : 32/300, Learning Rate : 0.0074547054246068
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.73it/s, train_loss_batch=tf.Tensor(0.18583521, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.39it/s, test_loss_batch=tf.Tensor(0.80843127, shape=(), dtype=float32)]
# Train Loss : 0.29096731543540955, Train Acc : 89.7959976196289
# Test Loss :0.344649076461792, Test Acc: 88.59000396728516
# Best Acc : 88.59000396728516
#
# Epoch : 33/300, Learning Rate : 0.0074532534927129745
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.11162837, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.71it/s, test_loss_batch=tf.Tensor(0.7870568, shape=(), dtype=float32)]
# Train Loss : 0.28720253705978394, Train Acc : 89.9800033569336
# Test Loss :0.34326615929603577, Test Acc: 88.86000061035156
# Best Acc : 88.86000061035156
#
# Epoch : 34/300, Learning Rate : 0.007451801095157862
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.17417617, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.75it/s, test_loss_batch=tf.Tensor(0.72133505, shape=(), dtype=float32)]
# Train Loss : 0.2762448489665985, Train Acc : 90.37000274658203
# Test Loss :0.3352195918560028, Test Acc: 89.08000183105469
# Best Acc : 89.08000183105469
#
# Epoch : 35/300, Learning Rate : 0.007450350560247898
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.59it/s, train_loss_batch=tf.Tensor(0.12949947, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.55it/s, test_loss_batch=tf.Tensor(0.6835072, shape=(), dtype=float32)]
# Train Loss : 0.27549049258232117, Train Acc : 90.16199493408203
# Test Loss :0.33330219984054565, Test Acc: 89.20000457763672
# Best Acc : 89.20000457763672
#
# Epoch : 36/300, Learning Rate : 0.0074489000253379345
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.17239824, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 30.55it/s, test_loss_batch=tf.Tensor(0.9333365, shape=(), dtype=float32)]
# Train Loss : 0.2697733938694, Train Acc : 90.52400207519531
# Test Loss :0.3494308888912201, Test Acc: 88.76000213623047
# Best Acc : 89.20000457763672
#
# Epoch : 37/300, Learning Rate : 0.0074474504217505455
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.72it/s, train_loss_batch=tf.Tensor(0.12161428, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.57it/s, test_loss_batch=tf.Tensor(0.5103096, shape=(), dtype=float32)]
# Train Loss : 0.26158225536346436, Train Acc : 90.8479995727539
# Test Loss :0.3244032859802246, Test Acc: 89.20000457763672
# Best Acc : 89.20000457763672
#
# Epoch : 38/300, Learning Rate : 0.007446001749485731
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.08924709, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.06it/s, test_loss_batch=tf.Tensor(0.5897091, shape=(), dtype=float32)]
# Train Loss : 0.2605215311050415, Train Acc : 90.85800170898438
# Test Loss :0.33349353075027466, Test Acc: 89.11000061035156
# Best Acc : 89.20000457763672
#
# Epoch : 39/300, Learning Rate : 0.007444553077220917
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.14784904, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.96it/s, test_loss_batch=tf.Tensor(0.5547692, shape=(), dtype=float32)]
# Train Loss : 0.2519104778766632, Train Acc : 91.13800048828125
# Test Loss :0.3203519582748413, Test Acc: 89.34000396728516
# Best Acc : 89.34000396728516
#
# Epoch : 40/300, Learning Rate : 0.007443104404956102
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.12505849, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.61it/s, test_loss_batch=tf.Tensor(0.69798815, shape=(), dtype=float32)]
# Train Loss : 0.2512178122997284, Train Acc : 91.18400573730469
# Test Loss :0.334655225276947, Test Acc: 89.25
# Best Acc : 89.34000396728516
#
# Epoch : 41/300, Learning Rate : 0.00744165712967515
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.098601356, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.92it/s, test_loss_batch=tf.Tensor(0.7265298, shape=(), dtype=float32)]
# Train Loss : 0.24209778010845184, Train Acc : 91.51800537109375
# Test Loss :0.32735249400138855, Test Acc: 89.42000579833984
# Best Acc : 89.42000579833984
#
# Epoch : 42/300, Learning Rate : 0.007440210320055485
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.07381998, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.05it/s, test_loss_batch=tf.Tensor(0.83740395, shape=(), dtype=float32)]
# Train Loss : 0.2398543804883957, Train Acc : 91.46800231933594
# Test Loss :0.33655840158462524, Test Acc: 89.25
# Best Acc : 89.42000579833984
#
# Epoch : 43/300, Learning Rate : 0.007438763976097107
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.79it/s, train_loss_batch=tf.Tensor(0.19745219, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.08it/s, test_loss_batch=tf.Tensor(0.7644393, shape=(), dtype=float32)]
# Train Loss : 0.23668518662452698, Train Acc : 91.51800537109375
# Test Loss :0.3403446078300476, Test Acc: 89.19000244140625
# Best Acc : 89.42000579833984
#
# Epoch : 44/300, Learning Rate : 0.007437318097800016
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.111214474, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.93it/s, test_loss_batch=tf.Tensor(0.774765, shape=(), dtype=float32)]
# Train Loss : 0.2314801961183548, Train Acc : 91.73200225830078
# Test Loss :0.3309256434440613, Test Acc: 89.37000274658203
# Best Acc : 89.42000579833984
#
# Epoch : 45/300, Learning Rate : 0.0074358731508255005
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.59it/s, train_loss_batch=tf.Tensor(0.114218354, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.09it/s, test_loss_batch=tf.Tensor(0.55988216, shape=(), dtype=float32)]
# Train Loss : 0.23020043969154358, Train Acc : 91.86199951171875
# Test Loss :0.33590295910835266, Test Acc: 89.24000549316406
# Best Acc : 89.42000579833984
#
# Epoch : 46/300, Learning Rate : 0.007434427738189697
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.73it/s, train_loss_batch=tf.Tensor(0.13750097, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.72it/s, test_loss_batch=tf.Tensor(0.70778996, shape=(), dtype=float32)]
# Train Loss : 0.2223609983921051, Train Acc : 92.1780014038086
# Test Loss :0.3311161398887634, Test Acc: 89.55000305175781
# Best Acc : 89.55000305175781
#
# Epoch : 47/300, Learning Rate : 0.007432983722537756
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.05554192, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.31it/s, test_loss_batch=tf.Tensor(0.6229665, shape=(), dtype=float32)]
# Train Loss : 0.22403199970722198, Train Acc : 92.18199920654297
# Test Loss :0.33342912793159485, Test Acc: 89.56999969482422
# Best Acc : 89.56999969482422
#
# Epoch : 48/300, Learning Rate : 0.007431540172547102
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.096880175, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.61it/s, test_loss_batch=tf.Tensor(0.5507577, shape=(), dtype=float32)]
# Train Loss : 0.21315892040729523, Train Acc : 92.52200317382812
# Test Loss :0.32739078998565674, Test Acc: 89.7800064086914
# Best Acc : 89.7800064086914
#
# Epoch : 49/300, Learning Rate : 0.007430097553879023
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.050095946, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.56it/s, test_loss_batch=tf.Tensor(1.0006, shape=(), dtype=float32)]
# Train Loss : 0.2124858945608139, Train Acc : 92.56600189208984
# Test Loss :0.3352890908718109, Test Acc: 89.79000091552734
# Best Acc : 89.79000091552734
#
# Epoch : 50/300, Learning Rate : 0.0074286554008722305
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.11360456, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.58it/s, test_loss_batch=tf.Tensor(0.6520993, shape=(), dtype=float32)]
# Train Loss : 0.20706452429294586, Train Acc : 92.69200134277344
# Test Loss :0.332045316696167, Test Acc: 89.6500015258789
# Best Acc : 89.79000091552734
#
# Epoch : 51/300, Learning Rate : 0.0074272132478654385
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.06959711, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.05it/s, test_loss_batch=tf.Tensor(0.80894536, shape=(), dtype=float32)]
# Train Loss : 0.2052111178636551, Train Acc : 92.83200073242188
# Test Loss :0.33165764808654785, Test Acc: 89.70999908447266
# Best Acc : 89.79000091552734
#
# Epoch : 52/300, Learning Rate : 0.007425771560519934
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.72it/s, train_loss_batch=tf.Tensor(0.022086848, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.06it/s, test_loss_batch=tf.Tensor(0.92121184, shape=(), dtype=float32)]
# Train Loss : 0.20033586025238037, Train Acc : 92.97599792480469
# Test Loss :0.3384998142719269, Test Acc: 89.70000457763672
# Best Acc : 89.79000091552734
#
# Epoch : 53/300, Learning Rate : 0.0074243308044970036
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.15147448, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.96it/s, test_loss_batch=tf.Tensor(0.75791746, shape=(), dtype=float32)]
# Train Loss : 0.19863994419574738, Train Acc : 92.90399932861328
# Test Loss :0.3523790240287781, Test Acc: 89.22000122070312
# Best Acc : 89.79000091552734
#
# Epoch : 54/300, Learning Rate : 0.007422890514135361
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.11296375, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.93it/s, test_loss_batch=tf.Tensor(0.58709425, shape=(), dtype=float32)]
# Train Loss : 0.19669172167778015, Train Acc : 93.05999755859375
# Test Loss :0.33664748072624207, Test Acc: 89.55000305175781
# Best Acc : 89.79000091552734
#
# Epoch : 55/300, Learning Rate : 0.0074214511550962925
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.12791839, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.92it/s, test_loss_batch=tf.Tensor(0.98386526, shape=(), dtype=float32)]
# Train Loss : 0.19434471428394318, Train Acc : 93.04800415039062
# Test Loss :0.3396386206150055, Test Acc: 89.7300033569336
# Best Acc : 89.79000091552734
#
# Epoch : 56/300, Learning Rate : 0.007420012261718512
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.60it/s, train_loss_batch=tf.Tensor(0.065219745, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.99it/s, test_loss_batch=tf.Tensor(0.74653995, shape=(), dtype=float32)]
# Train Loss : 0.18543311953544617, Train Acc : 93.37799835205078
# Test Loss :0.3420582711696625, Test Acc: 89.70999908447266
# Best Acc : 89.79000091552734
#
# Epoch : 57/300, Learning Rate : 0.007418573834002018
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.098193966, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.01it/s, test_loss_batch=tf.Tensor(0.76127756, shape=(), dtype=float32)]
# Train Loss : 0.18296919763088226, Train Acc : 93.55000305175781
# Test Loss :0.35012394189834595, Test Acc: 89.6500015258789
# Best Acc : 89.79000091552734
#
# Epoch : 58/300, Learning Rate : 0.007417135406285524
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.77it/s, train_loss_batch=tf.Tensor(0.079557315, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.89it/s, test_loss_batch=tf.Tensor(0.7068175, shape=(), dtype=float32)]
# Train Loss : 0.18027319014072418, Train Acc : 93.55400085449219
# Test Loss :0.33138567209243774, Test Acc: 89.75
# Best Acc : 89.79000091552734
#
# Epoch : 59/300, Learning Rate : 0.007415697909891605
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.10061093, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.03it/s, test_loss_batch=tf.Tensor(0.85319555, shape=(), dtype=float32)]
# Train Loss : 0.17812329530715942, Train Acc : 93.6259994506836
# Test Loss :0.3345189094543457, Test Acc: 89.94000244140625
# Best Acc : 89.94000244140625
#
# Epoch : 60/300, Learning Rate : 0.007414261344820261
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.08082242, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.35it/s, test_loss_batch=tf.Tensor(1.0191694, shape=(), dtype=float32)]
# Train Loss : 0.17495346069335938, Train Acc : 93.79199981689453
# Test Loss :0.3322898745536804, Test Acc: 90.16999816894531
# Best Acc : 90.16999816894531
#
# Epoch : 61/300, Learning Rate : 0.005559619050472975
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.037151266, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 42.62it/s, test_loss_batch=tf.Tensor(0.8077421, shape=(), dtype=float32)]
# Train Loss : 0.16161732375621796, Train Acc : 94.33000183105469
# Test Loss :0.3243509829044342, Test Acc: 90.13999938964844
# Best Acc : 90.16999816894531
#
# Epoch : 62/300, Learning Rate : 0.005558542441576719
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.028011318, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.17it/s, test_loss_batch=tf.Tensor(0.84059733, shape=(), dtype=float32)]
# Train Loss : 0.1541372537612915, Train Acc : 94.64600372314453
# Test Loss :0.3333267569541931, Test Acc: 90.11000061035156
# Best Acc : 90.16999816894531
#
# Epoch : 63/300, Learning Rate : 0.005557466298341751
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.03254422, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.73it/s, test_loss_batch=tf.Tensor(0.43849254, shape=(), dtype=float32)]
# Train Loss : 0.1483350396156311, Train Acc : 94.91600036621094
# Test Loss :0.3296225368976593, Test Acc: 90.19000244140625
# Best Acc : 90.19000244140625
#
# Epoch : 64/300, Learning Rate : 0.005556389689445496
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.03613477, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.90it/s, test_loss_batch=tf.Tensor(0.9398587, shape=(), dtype=float32)]
# Train Loss : 0.14810410141944885, Train Acc : 94.70600128173828
# Test Loss :0.34073159098625183, Test Acc: 90.18000030517578
# Best Acc : 90.19000244140625
#
# Epoch : 65/300, Learning Rate : 0.005555314011871815
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.051745683, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.68it/s, test_loss_batch=tf.Tensor(0.9564446, shape=(), dtype=float32)]
# Train Loss : 0.14005157351493835, Train Acc : 95.03399658203125
# Test Loss :0.3414786756038666, Test Acc: 90.24000549316406
# Best Acc : 90.24000549316406
#
# Epoch : 66/300, Learning Rate : 0.0055542392656207085
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.74it/s, train_loss_batch=tf.Tensor(0.08001006, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.50it/s, test_loss_batch=tf.Tensor(0.93082595, shape=(), dtype=float32)]
# Train Loss : 0.1437748372554779, Train Acc : 94.91199493408203
# Test Loss :0.33516258001327515, Test Acc: 90.3800048828125
# Best Acc : 90.3800048828125
#
# Epoch : 67/300, Learning Rate : 0.005553164519369602
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.10089693, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(0.8757162, shape=(), dtype=float32)]
# Train Loss : 0.13843213021755219, Train Acc : 95.0739974975586
# Test Loss :0.339618444442749, Test Acc: 90.27000427246094
# Best Acc : 90.3800048828125
#
# Epoch : 68/300, Learning Rate : 0.005552090238779783
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.61it/s, train_loss_batch=tf.Tensor(0.07434617, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.97it/s, test_loss_batch=tf.Tensor(1.0191834, shape=(), dtype=float32)]
# Train Loss : 0.14010846614837646, Train Acc : 95.04600524902344
# Test Loss :0.34255483746528625, Test Acc: 90.13999938964844
# Best Acc : 90.3800048828125
#
# Epoch : 69/300, Learning Rate : 0.005551016423851252
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.1285027, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.61it/s, test_loss_batch=tf.Tensor(1.0963721, shape=(), dtype=float32)]
# Train Loss : 0.13745059072971344, Train Acc : 95.12799835205078
# Test Loss :0.3314949572086334, Test Acc: 90.61000061035156
# Best Acc : 90.61000061035156
#
# Epoch : 70/300, Learning Rate : 0.00554994260892272
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.60it/s, train_loss_batch=tf.Tensor(0.05537746, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.63it/s, test_loss_batch=tf.Tensor(1.0236492, shape=(), dtype=float32)]
# Train Loss : 0.1342725306749344, Train Acc : 95.20000457763672
# Test Loss :0.35068076848983765, Test Acc: 90.2300033569336
# Best Acc : 90.61000061035156
#
# Epoch : 71/300, Learning Rate : 0.005548869725316763
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.73it/s, train_loss_batch=tf.Tensor(0.048915472, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.82it/s, test_loss_batch=tf.Tensor(1.0667462, shape=(), dtype=float32)]
# Train Loss : 0.13280071318149567, Train Acc : 95.44599914550781
# Test Loss :0.34056657552719116, Test Acc: 90.5999984741211
# Best Acc : 90.61000061035156
#
# Epoch : 72/300, Learning Rate : 0.005547796841710806
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.043840606, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.97it/s, test_loss_batch=tf.Tensor(0.7538591, shape=(), dtype=float32)]
# Train Loss : 0.13131721317768097, Train Acc : 95.33599853515625
# Test Loss :0.3355026841163635, Test Acc: 90.2300033569336
# Best Acc : 90.61000061035156
#
# Epoch : 73/300, Learning Rate : 0.0055467248894274235
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.10034468, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.00it/s, test_loss_batch=tf.Tensor(0.84202534, shape=(), dtype=float32)]
# Train Loss : 0.13004736602306366, Train Acc : 95.42000579833984
# Test Loss :0.3406341075897217, Test Acc: 90.1300048828125
# Best Acc : 90.61000061035156
#
# Epoch : 74/300, Learning Rate : 0.005545652937144041
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.104653955, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.93it/s, test_loss_batch=tf.Tensor(1.1271579, shape=(), dtype=float32)]
# Train Loss : 0.12996934354305267, Train Acc : 95.43799591064453
# Test Loss :0.34212833642959595, Test Acc: 90.55999755859375
# Best Acc : 90.61000061035156
#
# Epoch : 75/300, Learning Rate : 0.005544581916183233
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.61it/s, train_loss_batch=tf.Tensor(0.050391354, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.84it/s, test_loss_batch=tf.Tensor(0.9320395, shape=(), dtype=float32)]
# Train Loss : 0.12479802221059799, Train Acc : 95.46800231933594
# Test Loss :0.34357476234436035, Test Acc: 90.58999633789062
# Best Acc : 90.61000061035156
#
# Epoch : 76/300, Learning Rate : 0.005543510429561138
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.054306872, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.66it/s, test_loss_batch=tf.Tensor(1.4780197, shape=(), dtype=float32)]
# Train Loss : 0.12475385516881943, Train Acc : 95.50799560546875
# Test Loss :0.3567832112312317, Test Acc: 90.62000274658203
# Best Acc : 90.62000274658203
#
# Epoch : 77/300, Learning Rate : 0.005542439874261618
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.021913374, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 42.68it/s, test_loss_batch=tf.Tensor(1.1988475, shape=(), dtype=float32)]
# Train Loss : 0.12024367600679398, Train Acc : 95.75399780273438
# Test Loss :0.3582559823989868, Test Acc: 90.4000015258789
# Best Acc : 90.62000274658203
#
# Epoch : 78/300, Learning Rate : 0.0055413697846233845
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.20099863, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.11it/s, test_loss_batch=tf.Tensor(1.3036015, shape=(), dtype=float32)]
# Train Loss : 0.11927881836891174, Train Acc : 95.85199737548828
# Test Loss :0.3497856855392456, Test Acc: 90.62999725341797
# Best Acc : 90.62999725341797
#
# Epoch : 79/300, Learning Rate : 0.005540300160646439
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.59it/s, train_loss_batch=tf.Tensor(0.025222365, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.44it/s, test_loss_batch=tf.Tensor(0.93273276, shape=(), dtype=float32)]
# Train Loss : 0.12227224558591843, Train Acc : 95.67000579833984
# Test Loss :0.34442371129989624, Test Acc: 90.66999816894531
# Best Acc : 90.66999816894531
#
# Epoch : 80/300, Learning Rate : 0.00553923100233078
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.022928024, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.25it/s, test_loss_batch=tf.Tensor(1.1252037, shape=(), dtype=float32)]
# Train Loss : 0.11210697889328003, Train Acc : 96.00199890136719
# Test Loss :0.34747007489204407, Test Acc: 90.5999984741211
# Best Acc : 90.66999816894531
#
# Epoch : 81/300, Learning Rate : 0.005538162309676409
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.074811295, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.82it/s, test_loss_batch=tf.Tensor(0.8272961, shape=(), dtype=float32)]
# Train Loss : 0.11854712665081024, Train Acc : 95.83799743652344
# Test Loss :0.33502906560897827, Test Acc: 90.76000213623047
# Best Acc : 90.76000213623047
#
# Epoch : 82/300, Learning Rate : 0.00553709315136075
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.57it/s, train_loss_batch=tf.Tensor(0.03395826, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.46it/s, test_loss_batch=tf.Tensor(1.2588048, shape=(), dtype=float32)]
# Train Loss : 0.11868447065353394, Train Acc : 95.77000427246094
# Test Loss :0.3533751368522644, Test Acc: 90.56999969482422
# Best Acc : 90.76000213623047
#
# Epoch : 83/300, Learning Rate : 0.005536024924367666
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.0618636, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.91it/s, test_loss_batch=tf.Tensor(1.4619188, shape=(), dtype=float32)]
# Train Loss : 0.10979737341403961, Train Acc : 96.052001953125
# Test Loss :0.36489272117614746, Test Acc: 90.4800033569336
# Best Acc : 90.76000213623047
#
# Epoch : 84/300, Learning Rate : 0.005534957628697157
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.07104872, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.79it/s, test_loss_batch=tf.Tensor(1.4491625, shape=(), dtype=float32)]
# Train Loss : 0.11200691014528275, Train Acc : 96.10000610351562
# Test Loss :0.35555779933929443, Test Acc: 90.63999938964844
# Best Acc : 90.76000213623047
#
# Epoch : 85/300, Learning Rate : 0.005533890333026648
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.76it/s, train_loss_batch=tf.Tensor(0.064045526, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.56it/s, test_loss_batch=tf.Tensor(1.3587401, shape=(), dtype=float32)]
# Train Loss : 0.1104542464017868, Train Acc : 96.09199523925781
# Test Loss :0.3560321033000946, Test Acc: 90.52000427246094
# Best Acc : 90.76000213623047
#
# Epoch : 86/300, Learning Rate : 0.0055328235030174255
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.018413505, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.96it/s, test_loss_batch=tf.Tensor(1.0058867, shape=(), dtype=float32)]
# Train Loss : 0.10791581869125366, Train Acc : 96.23600006103516
# Test Loss :0.3363282382488251, Test Acc: 91.00999450683594
# Best Acc : 91.00999450683594
#
# Epoch : 87/300, Learning Rate : 0.005531757138669491
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.021414036, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.41it/s, test_loss_batch=tf.Tensor(1.4693146, shape=(), dtype=float32)]
# Train Loss : 0.10789024829864502, Train Acc : 96.16400146484375
# Test Loss :0.3526044189929962, Test Acc: 90.73999786376953
# Best Acc : 91.00999450683594
#
# Epoch : 88/300, Learning Rate : 0.005530690774321556
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.60it/s, train_loss_batch=tf.Tensor(0.015303761, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.85it/s, test_loss_batch=tf.Tensor(1.5444136, shape=(), dtype=float32)]
# Train Loss : 0.10864569246768951, Train Acc : 96.19200134277344
# Test Loss :0.3595517873764038, Test Acc: 90.79000091552734
# Best Acc : 91.00999450683594
#
# Epoch : 89/300, Learning Rate : 0.005529624875634909
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.73it/s, train_loss_batch=tf.Tensor(0.12917054, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.91it/s, test_loss_batch=tf.Tensor(1.3730723, shape=(), dtype=float32)]
# Train Loss : 0.10454363375902176, Train Acc : 96.29000091552734
# Test Loss :0.35830622911453247, Test Acc: 90.72000122070312
# Best Acc : 91.00999450683594
#
# Epoch : 90/300, Learning Rate : 0.005528559908270836
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.0532381, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.46it/s, test_loss_batch=tf.Tensor(1.1113298, shape=(), dtype=float32)]
# Train Loss : 0.10664206743240356, Train Acc : 96.2459945678711
# Test Loss :0.3532596230506897, Test Acc: 90.51000213623047
# Best Acc : 91.00999450683594
#
# Epoch : 91/300, Learning Rate : 0.004145621322095394
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.11771165, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.09it/s, test_loss_batch=tf.Tensor(1.3299888, shape=(), dtype=float32)]
# Train Loss : 0.09391696751117706, Train Acc : 96.697998046875
# Test Loss :0.35375088453292847, Test Acc: 90.8499984741211
# Best Acc : 91.00999450683594
#
# Epoch : 92/300, Learning Rate : 0.004144823178648949
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.028135646, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.64it/s, test_loss_batch=tf.Tensor(1.308932, shape=(), dtype=float32)]
# Train Loss : 0.09075114876031876, Train Acc : 96.87200164794922
# Test Loss :0.3602406680583954, Test Acc: 90.83000183105469
# Best Acc : 91.00999450683594
#
# Epoch : 93/300, Learning Rate : 0.0041440255008637905
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.012123482, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(1.3094809, shape=(), dtype=float32)]
# Train Loss : 0.08790423721075058, Train Acc : 96.87200164794922
# Test Loss :0.35122939944267273, Test Acc: 91.02999877929688
# Best Acc : 91.02999877929688
#
# Epoch : 94/300, Learning Rate : 0.004143227357417345
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.013362599, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.03it/s, test_loss_batch=tf.Tensor(1.1260135, shape=(), dtype=float32)]
# Train Loss : 0.08929459005594254, Train Acc : 96.87200164794922
# Test Loss :0.3511312007904053, Test Acc: 90.94000244140625
# Best Acc : 91.02999877929688
#
# Epoch : 95/300, Learning Rate : 0.004142429679632187
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.0651297, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.07it/s, test_loss_batch=tf.Tensor(1.1478295, shape=(), dtype=float32)]
# Train Loss : 0.08685225248336792, Train Acc : 96.89400482177734
# Test Loss :0.3547230660915375, Test Acc: 91.04999542236328
# Best Acc : 91.04999542236328
#
# Epoch : 96/300, Learning Rate : 0.004141632933169603
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.058534086, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.77it/s, test_loss_batch=tf.Tensor(1.0720708, shape=(), dtype=float32)]
# Train Loss : 0.08065194636583328, Train Acc : 97.24199676513672
# Test Loss :0.34789571166038513, Test Acc: 91.14999389648438
# Best Acc : 91.14999389648438
#
# Epoch : 97/300, Learning Rate : 0.00414083618670702
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.013147673, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.79it/s, test_loss_batch=tf.Tensor(1.4664725, shape=(), dtype=float32)]
# Train Loss : 0.08217058330774307, Train Acc : 97.0979995727539
# Test Loss :0.36959969997406006, Test Acc: 90.4800033569336
# Best Acc : 91.14999389648438
#
# Epoch : 98/300, Learning Rate : 0.004140039905905724
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.54it/s, train_loss_batch=tf.Tensor(0.007720962, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(1.265151, shape=(), dtype=float32)]
# Train Loss : 0.08356843888759613, Train Acc : 97.08000183105469
# Test Loss :0.34666651487350464, Test Acc: 90.8699951171875
# Best Acc : 91.14999389648438
#
# Epoch : 99/300, Learning Rate : 0.004139243625104427
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.70it/s, train_loss_batch=tf.Tensor(0.0061339634, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.92it/s, test_loss_batch=tf.Tensor(1.2606874, shape=(), dtype=float32)]
# Train Loss : 0.08283048123121262, Train Acc : 97.1259994506836
# Test Loss :0.35299625992774963, Test Acc: 90.91999816894531
# Best Acc : 91.14999389648438
#
# ...
# Testing...
# 100% 40/40 [00:00<00:00, 43.48it/s, test_loss_batch=tf.Tensor(1.1305254, shape=(), dtype=float32)]
# Train Loss : 0.01881592907011509, Train Acc : 99.34600067138672
# Test Loss :0.43889451026916504, Test Acc: 91.44999694824219
# Best Acc : 91.90999603271484
#
# Epoch : 265/300, Learning Rate : 0.0009518753504380584
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.00010665688, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.04it/s, test_loss_batch=tf.Tensor(1.2828047, shape=(), dtype=float32)]
# Train Loss : 0.017089905217289925, Train Acc : 99.4020004272461
# Test Loss :0.4359753727912903, Test Acc: 91.79999542236328
# Best Acc : 91.90999603271484
#
# Epoch : 266/300, Learning Rate : 0.000951697991695255
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.0105574, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(1.2237874, shape=(), dtype=float32)]
# Train Loss : 0.018324287608265877, Train Acc : 99.36799621582031
# Test Loss :0.43435972929000854, Test Acc: 91.62999725341797
# Best Acc : 91.90999603271484
#
# Epoch : 267/300, Learning Rate : 0.0009515207493677735
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.72it/s, train_loss_batch=tf.Tensor(0.00041065356, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.89it/s, test_loss_batch=tf.Tensor(1.2526897, shape=(), dtype=float32)]
# Train Loss : 0.018152691423892975, Train Acc : 99.37799835205078
# Test Loss :0.4313165545463562, Test Acc: 91.64999389648438
# Best Acc : 91.90999603271484
#
# Epoch : 268/300, Learning Rate : 0.0009513433906249702
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.00024334446, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.97it/s, test_loss_batch=tf.Tensor(1.2369586, shape=(), dtype=float32)]
# Train Loss : 0.01843102090060711, Train Acc : 99.3759994506836
# Test Loss :0.4341641068458557, Test Acc: 91.68000030517578
# Best Acc : 91.90999603271484
#
# Epoch : 269/300, Learning Rate : 0.0009511662647128105
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.0074085584, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.93it/s, test_loss_batch=tf.Tensor(1.2203376, shape=(), dtype=float32)]
# Train Loss : 0.017457393929362297, Train Acc : 99.39800262451172
# Test Loss :0.43070730566978455, Test Acc: 91.80999755859375
# Best Acc : 91.90999603271484
#
# Epoch : 270/300, Learning Rate : 0.0009509891970083117
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.010685812, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.04it/s, test_loss_batch=tf.Tensor(1.3062238, shape=(), dtype=float32)]
# Train Loss : 0.019038239493966103, Train Acc : 99.38200378417969
# Test Loss :0.4435862898826599, Test Acc: 91.57999420166016
# Best Acc : 91.90999603271484
#
# Epoch : 271/300, Learning Rate : 0.0007131091551855206
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.021142613, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.99it/s, test_loss_batch=tf.Tensor(1.3484682, shape=(), dtype=float32)]
# Train Loss : 0.017202334478497505, Train Acc : 99.41400146484375
# Test Loss :0.4371805191040039, Test Acc: 91.69999694824219
# Best Acc : 91.90999603271484
#
# Epoch : 272/300, Learning Rate : 0.0007129764417186379
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.0009206788, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.84it/s, test_loss_batch=tf.Tensor(1.3830042, shape=(), dtype=float32)]
# Train Loss : 0.01650667004287243, Train Acc : 99.39399719238281
# Test Loss :0.4379516541957855, Test Acc: 91.77999877929688
# Best Acc : 91.90999603271484
#
# Epoch : 273/300, Learning Rate : 0.0007128437864594162
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.00021607315, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.15it/s, test_loss_batch=tf.Tensor(1.4650061, shape=(), dtype=float32)]
# Train Loss : 0.017667464911937714, Train Acc : 99.43600463867188
# Test Loss :0.4458162784576416, Test Acc: 91.70999908447266
# Best Acc : 91.90999603271484
#
# Epoch : 274/300, Learning Rate : 0.0007127110729925334
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.017926136, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.04it/s, test_loss_batch=tf.Tensor(1.5059516, shape=(), dtype=float32)]
# Train Loss : 0.01754777692258358, Train Acc : 99.42399597167969
# Test Loss :0.44353801012039185, Test Acc: 91.83999633789062
# Best Acc : 91.90999603271484
#
# Epoch : 275/300, Learning Rate : 0.0007125785341486335
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.0018258095, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.91it/s, test_loss_batch=tf.Tensor(1.3712184, shape=(), dtype=float32)]
# Train Loss : 0.014930429868400097, Train Acc : 99.50199890136719
# Test Loss :0.44140273332595825, Test Acc: 91.7699966430664
# Best Acc : 91.90999603271484
#
# Epoch : 276/300, Learning Rate : 0.0007124460535123944
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.00086538575, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.95it/s, test_loss_batch=tf.Tensor(1.2799581, shape=(), dtype=float32)]
# Train Loss : 0.01615353487432003, Train Acc : 99.49200439453125
# Test Loss :0.4375382363796234, Test Acc: 91.7699966430664
# Best Acc : 91.90999603271484
#
# Epoch : 277/300, Learning Rate : 0.0007123135728761554
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.65it/s, train_loss_batch=tf.Tensor(0.0004613263, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.93it/s, test_loss_batch=tf.Tensor(1.3863161, shape=(), dtype=float32)]
# Train Loss : 0.01611810363829136, Train Acc : 99.43600463867188
# Test Loss :0.44392022490501404, Test Acc: 91.73999786376953
# Best Acc : 91.90999603271484
#
# Epoch : 278/300, Learning Rate : 0.0007121811504475772
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.0026581294, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.96it/s, test_loss_batch=tf.Tensor(1.3241594, shape=(), dtype=float32)]
# Train Loss : 0.014300275593996048, Train Acc : 99.4739990234375
# Test Loss :0.44178643822669983, Test Acc: 91.69999694824219
# Best Acc : 91.90999603271484
#
# Epoch : 279/300, Learning Rate : 0.00071204878622666
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.75it/s, train_loss_batch=tf.Tensor(0.0006832642, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.54it/s, test_loss_batch=tf.Tensor(1.4404254, shape=(), dtype=float32)]
# Train Loss : 0.01697615534067154, Train Acc : 99.40399932861328
# Test Loss :0.44261497259140015, Test Acc: 91.83999633789062
# Best Acc : 91.90999603271484
#
# Epoch : 280/300, Learning Rate : 0.0007119164220057428
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.0007357074, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.01it/s, test_loss_batch=tf.Tensor(1.180086, shape=(), dtype=float32)]
# Train Loss : 0.01590902917087078, Train Acc : 99.43600463867188
# Test Loss :0.43891406059265137, Test Acc: 91.75
# Best Acc : 91.90999603271484
#
# Epoch : 281/300, Learning Rate : 0.0007117841159924865
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.050359357, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.01it/s, test_loss_batch=tf.Tensor(1.3062723, shape=(), dtype=float32)]
# Train Loss : 0.017320577055215836, Train Acc : 99.4000015258789
# Test Loss :0.44321900606155396, Test Acc: 91.80999755859375
# Best Acc : 91.90999603271484
#
# Epoch : 282/300, Learning Rate : 0.000711651926394552
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(8.399856e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.08it/s, test_loss_batch=tf.Tensor(1.261421, shape=(), dtype=float32)]
# Train Loss : 0.015573929995298386, Train Acc : 99.45399475097656
# Test Loss :0.4419766962528229, Test Acc: 91.72999572753906
# Best Acc : 91.90999603271484
#
# Epoch : 283/300, Learning Rate : 0.0007115197367966175
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.62it/s, train_loss_batch=tf.Tensor(0.00044520647, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.08it/s, test_loss_batch=tf.Tensor(1.36079, shape=(), dtype=float32)]
# Train Loss : 0.017158564180135727, Train Acc : 99.44200134277344
# Test Loss :0.44731488823890686, Test Acc: 91.6199951171875
# Best Acc : 91.90999603271484
#
# Epoch : 284/300, Learning Rate : 0.0007113876636140049
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.00081537094, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.73it/s, test_loss_batch=tf.Tensor(1.4191376, shape=(), dtype=float32)]
# Train Loss : 0.016031820327043533, Train Acc : 99.46200561523438
# Test Loss :0.44640088081359863, Test Acc: 91.68999481201172
# Best Acc : 91.90999603271484
#
# Epoch : 285/300, Learning Rate : 0.0007112555904313922
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.58it/s, train_loss_batch=tf.Tensor(0.0003455821, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.05it/s, test_loss_batch=tf.Tensor(1.29188, shape=(), dtype=float32)]
# Train Loss : 0.01621801033616066, Train Acc : 99.42399597167969
# Test Loss :0.4401869773864746, Test Acc: 91.82999420166016
# Best Acc : 91.90999603271484
#
# Epoch : 286/300, Learning Rate : 0.0007111234590411186
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.0004705845, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(1.3972118, shape=(), dtype=float32)]
# Train Loss : 0.016270343214273453, Train Acc : 99.45399475097656
# Test Loss :0.449613094329834, Test Acc: 91.65999603271484
# Best Acc : 91.90999603271484
#
# Epoch : 287/300, Learning Rate : 0.0007109915022738278
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.00025981222, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.78it/s, test_loss_batch=tf.Tensor(1.4034535, shape=(), dtype=float32)]
# Train Loss : 0.015130707062780857, Train Acc : 99.5260009765625
# Test Loss :0.4518584609031677, Test Acc: 91.65999603271484
# Best Acc : 91.90999603271484
#
# Epoch : 288/300, Learning Rate : 0.0007108596037141979
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.69it/s, train_loss_batch=tf.Tensor(0.0017812239, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.98it/s, test_loss_batch=tf.Tensor(1.2483011, shape=(), dtype=float32)]
# Train Loss : 0.01576138846576214, Train Acc : 99.45399475097656
# Test Loss :0.44424891471862793, Test Acc: 91.75999450683594
# Best Acc : 91.90999603271484
#
# Epoch : 289/300, Learning Rate : 0.000710727705154568
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.68it/s, train_loss_batch=tf.Tensor(0.00013368261, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.77it/s, test_loss_batch=tf.Tensor(1.2737181, shape=(), dtype=float32)]
# Train Loss : 0.015788935124874115, Train Acc : 99.50199890136719
# Test Loss :0.44623836874961853, Test Acc: 91.75
# Best Acc : 91.90999603271484
#
# Epoch : 290/300, Learning Rate : 0.0007105959230102599
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.0057165367, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.70it/s, test_loss_batch=tf.Tensor(1.3389823, shape=(), dtype=float32)]
# Train Loss : 0.01681506633758545, Train Acc : 99.45600128173828
# Test Loss :0.4456987977027893, Test Acc: 91.82999420166016
# Best Acc : 91.90999603271484
#
# Epoch : 291/300, Learning Rate : 0.0007104641408659518
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(0.00014679783, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.94it/s, test_loss_batch=tf.Tensor(1.2849905, shape=(), dtype=float32)]
# Train Loss : 0.016136091202497482, Train Acc : 99.44200134277344
# Test Loss :0.44005781412124634, Test Acc: 91.80999755859375
# Best Acc : 91.90999603271484
#
# Epoch : 292/300, Learning Rate : 0.0007103323005139828
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.59it/s, train_loss_batch=tf.Tensor(0.0005338768, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.94it/s, test_loss_batch=tf.Tensor(1.3770341, shape=(), dtype=float32)]
# Train Loss : 0.014812996610999107, Train Acc : 99.50199890136719
# Test Loss :0.4444521963596344, Test Acc: 91.63999938964844
# Best Acc : 91.90999603271484
#
# Epoch : 293/300, Learning Rate : 0.0007102006347849965
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.66it/s, train_loss_batch=tf.Tensor(6.5288725e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.90it/s, test_loss_batch=tf.Tensor(1.2069774, shape=(), dtype=float32)]
# Train Loss : 0.014929523691534996, Train Acc : 99.5
# Test Loss :0.44358548521995544, Test Acc: 91.72999572753906
# Best Acc : 91.90999603271484
#
# Epoch : 294/300, Learning Rate : 0.0007100690272636712
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.74it/s, train_loss_batch=tf.Tensor(0.0022524807, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.13it/s, test_loss_batch=tf.Tensor(1.1333174, shape=(), dtype=float32)]
# Train Loss : 0.014547633938491344, Train Acc : 99.5
# Test Loss :0.4347771108150482, Test Acc: 91.80999755859375
# Best Acc : 91.90999603271484
#
# Epoch : 295/300, Learning Rate : 0.0007099374197423458
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(6.182209e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.83it/s, test_loss_batch=tf.Tensor(1.2958934, shape=(), dtype=float32)]
# Train Loss : 0.014186842367053032, Train Acc : 99.4939956665039
# Test Loss :0.4456943869590759, Test Acc: 91.7699966430664
# Best Acc : 91.90999603271484
#
# Epoch : 296/300, Learning Rate : 0.0007098059286363423
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.64it/s, train_loss_batch=tf.Tensor(0.00096094527, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.07it/s, test_loss_batch=tf.Tensor(1.3483043, shape=(), dtype=float32)]
# Train Loss : 0.01629824750125408, Train Acc : 99.45800018310547
# Test Loss :0.44398871064186096, Test Acc: 91.64999389648438
# Best Acc : 91.90999603271484
#
# Epoch : 297/300, Learning Rate : 0.0007096744375303388
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.63it/s, train_loss_batch=tf.Tensor(0.001588425, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.74it/s, test_loss_batch=tf.Tensor(1.3588747, shape=(), dtype=float32)]
# Train Loss : 0.016028065234422684, Train Acc : 99.4520034790039
# Test Loss :0.4420187473297119, Test Acc: 91.73999786376953
# Best Acc : 91.90999603271484
#
# Epoch : 298/300, Learning Rate : 0.0007095429464243352
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.01989976, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.09it/s, test_loss_batch=tf.Tensor(1.3266492, shape=(), dtype=float32)]
# Train Loss : 0.01582060381770134, Train Acc : 99.43800354003906
# Test Loss :0.4497947692871094, Test Acc: 91.54000091552734
# Best Acc : 91.90999603271484
#
# Epoch : 299/300, Learning Rate : 0.0007094115717336535
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.71it/s, train_loss_batch=tf.Tensor(0.0054407287, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 43.86it/s, test_loss_batch=tf.Tensor(1.3811547, shape=(), dtype=float32)]
# Train Loss : 0.016380174085497856, Train Acc : 99.44999694824219
# Test Loss :0.4487455487251282, Test Acc: 91.79999542236328
# Best Acc : 91.90999603271484
#
# Epoch : 300/300, Learning Rate : 0.0007092801970429718
# TRAINING...
# 100% 196/196 [00:13<00:00, 14.67it/s, train_loss_batch=tf.Tensor(0.010031977, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:00<00:00, 44.14it/s, test_loss_batch=tf.Tensor(1.3105624, shape=(), dtype=float32)]
# Train Loss : 0.016011547297239304, Train Acc : 99.41999816894531
# Test Loss :0.44669023156166077, Test Acc: 91.72999572753906
# Best Acc : 91.90999603271484

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.datasets import cifar10
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from get_model import get_model


# def normalization(train_images, test_images):
#     mean = np.mean(train_images, axis=(0, 1, 2, 3))
#     std = np.std(train_images, axis=(0, 1, 2, 3))
#     train_images = (train_images - mean) / (std + 1e-7)
#     test_images = (test_images - mean) / (std + 1e-7)
#     return train_images, test_images


# def load_images():
#     (train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

#     train_images = train_images.astype(np.float32)
#     test_images = test_images.astype(np.float32)

#     (train_images, test_images) = normalization(train_images, test_images)

#     train_labels = to_categorical(train_labels, 10)
#     test_labels = to_categorical(test_labels, 10)

#     # train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).shuffle(
#     #     buffer_size=10000).batch(batch_size)
#     # test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

#     return train_images, train_labels, test_images, test_labels
# if __name__ == '__main__':
#     print(tf.__version__)
#     print(keras.__version__)

#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#         # 텐서플로가 첫 번째 GPU만 사용하도록 제한
#         try:
#             print('start with GPU 7')
#             tf.config.experimental.set_visible_devices(gpus[7], 'GPU')
#             tf.config.experimental.set_memory_growth(gpus[7], True)
#         except RuntimeError as e:
#             # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
#             print(e)

#     training_epochs = 250
#     batch_size = 128
#     learning_rate = 0.1
#     momentum = 0.9
#     lr_decay = 1e-6
#     lr_drop = 20

#     tf.random.set_seed(777)

#     def lr_scheduler(epoch):
#         return learning_rate * (0.5 ** (epoch // lr_drop))

#     reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

#     train_images, train_labels, test_images, test_labels = load_images()

#     # data augmentation
#     datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip=True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images
#     # (std, mean, and principal components if ZCA whitening is applied).
#     datagen.fit(train_images)

#     model = get_model('vgg11')

#     optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate,
#                                         decay=1e-6, momentum=momentum, nesterov=True)
#     model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

#     model.fit_generator(datagen.flow(train_images, train_labels,
#                                      batch_size=batch_size), epochs=training_epochs, verbose=2, callbacks=[reduce_lr],
#                         steps_per_epoch=train_images.shape[0] // batch_size, validation_data=(test_images, test_labels))

#     model.save_weights('cifar10vgg_custom.h5')
