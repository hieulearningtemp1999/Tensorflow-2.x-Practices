# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/Tensorflow-2.x-Practices/Image Classification on CIFAR10
# Out:
# /content/gdrive/My Drive/Tensorflow-2.x-Practices/Image Classification on CIFAR10

# %%
# !python main.py -m "vgg19" -b 256 -lr 0.01 -e 300
# Out:
# 2021-10-06 00:36:38.803889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:39.042254: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:39.043335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.854840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.855759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.856646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.857649: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-10-06 00:36:41.857704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2021-10-06 00:36:41.863438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.864516: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.865748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.867448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.868323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.869081: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.869999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.870730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 00:36:41.871403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15435 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Device :  /device:GPU:0
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# Training samples :  50000
# Testing samples : 10000
# tcmalloc: large alloc 1228800000 bytes == 0x564e6d50e000 @  0x7f537d9cb1e7 0x7f537b54b46e 0x7f537b59bc7b 0x7f537b59bd18 0x7f537b657d79 0x7f537b65ae4c 0x7f537b779e7f 0x7f537b77ffb5 0x7f537b781e3d 0x7f537b783516 0x564e49fb0720 0x564e49fb02f9 0x7f537b6620db 0x564e4a0990b2 0x564e4a01f62d 0x564e4a01d9ee 0x564e49fb0bda 0x564e4a01f737 0x564e4a01d9ee 0x564e49eefe2b 0x564e4a01ffe4 0x564e4a01d9ee 0x564e49eefe2b 0x7f537b588ef7 0x564e49faf437 0x564e49faf240 0x564e4a022973 0x564e4a01d9ee 0x564e49fb0bda 0x564e4a01f737 0x564e4a01d9ee
# tcmalloc: large alloc 1228800000 bytes == 0x564e6d50e000 @  0x7f537d9cb1e7 0x7f537b54b46e 0x7f537b59bc7b 0x7f537b59bd18 0x7f537b657d79 0x7f537b65ae4c 0x7f537b779e7f 0x7f537b77ffb5 0x7f537b781e3d 0x7f537b783516 0x564e49fb0720 0x564e49fb02f9 0x7f537b6620db 0x564e4a099113 0x564e4a01f62d 0x564e4a01d9ee 0x564e4a01d6f3 0x564e4a0e74c2 0x564e4a0e783d 0x564e4a0e76e6 0x564e4a0bf163 0x564e4a0bee0c 0x7f537c7b5bf7 0x564e4a0becea
# Epoch : 1/300, Learning Rate : 0.009999999776482582
# TRAINING...
#   0% 0/196 [00:00<?, ?it/s]2021-10-06 00:36:51.008656: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-06 00:36:55.247251: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 100% 196/196 [00:36<00:00,  5.41it/s, train_loss_batch=tf.Tensor(1.4657686, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:02<00:00, 17.60it/s, test_loss_batch=tf.Tensor(1.4921194, shape=(), dtype=float32)]
# Train Loss : 1.6605305671691895, Train Acc : 38.26000213623047
# Test Loss :1.2679685354232788, Test Acc: 54.59000015258789
# Best Acc : 54.59000015258789
#
# Epoch : 2/300, Learning Rate : 0.009998040273785591
# TRAINING...
# 100% 196/196 [00:16<00:00, 11.98it/s, train_loss_batch=tf.Tensor(1.2841402, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(1.1817408, shape=(), dtype=float32)]
# Train Loss : 1.3069703578948975, Train Acc : 53.08399963378906
# Test Loss :1.0239506959915161, Test Acc: 63.58000183105469
# Best Acc : 63.58000183105469
#
# Epoch : 3/300, Learning Rate : 0.009996081702411175
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(1.1915152, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.44it/s, test_loss_batch=tf.Tensor(1.0980475, shape=(), dtype=float32)]
# Train Loss : 1.120723843574524, Train Acc : 60.26399612426758
# Test Loss :0.8844578862190247, Test Acc: 68.61000061035156
# Best Acc : 68.61000061035156
#
# Epoch : 4/300, Learning Rate : 0.009994122199714184
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.8953519, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.69it/s, test_loss_batch=tf.Tensor(0.8956107, shape=(), dtype=float32)]
# Train Loss : 0.9929888844490051, Train Acc : 65.052001953125
# Test Loss :0.7717006206512451, Test Acc: 73.25
# Best Acc : 73.25
#
# Epoch : 5/300, Learning Rate : 0.009992165490984917
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.71059465, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.62it/s, test_loss_batch=tf.Tensor(1.0006819, shape=(), dtype=float32)]
# Train Loss : 0.8962891101837158, Train Acc : 68.49200439453125
# Test Loss :0.6962066888809204, Test Acc: 75.72000122070312
# Best Acc : 75.72000122070312
#
# Epoch : 6/300, Learning Rate : 0.00999020878225565
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.73011005, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(1.0480514, shape=(), dtype=float32)]
# Train Loss : 0.8219876885414124, Train Acc : 71.19400024414062
# Test Loss :0.6585932374000549, Test Acc: 77.30000305175781
# Best Acc : 77.30000305175781
#
# Epoch : 7/300, Learning Rate : 0.009988253936171532
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.5119079, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.56it/s, test_loss_batch=tf.Tensor(1.1626675, shape=(), dtype=float32)]
# Train Loss : 0.7624008655548096, Train Acc : 73.32599639892578
# Test Loss :0.607765793800354, Test Acc: 79.83000183105469
# Best Acc : 79.83000183105469
#
# Epoch : 8/300, Learning Rate : 0.009986299090087414
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.58772767, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.52it/s, test_loss_batch=tf.Tensor(0.8615014, shape=(), dtype=float32)]
# Train Loss : 0.7125957012176514, Train Acc : 75.11799621582031
# Test Loss :0.561333179473877, Test Acc: 80.9800033569336
# Best Acc : 80.9800033569336
#
# Epoch : 9/300, Learning Rate : 0.00998434517532587
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.4746601, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.38it/s, test_loss_batch=tf.Tensor(0.90080774, shape=(), dtype=float32)]
# Train Loss : 0.6726430058479309, Train Acc : 76.71199798583984
# Test Loss :0.535853385925293, Test Acc: 82.05999755859375
# Best Acc : 82.05999755859375
#
# Epoch : 10/300, Learning Rate : 0.009982390329241753
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.4358801, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.46it/s, test_loss_batch=tf.Tensor(0.84802324, shape=(), dtype=float32)]
# Train Loss : 0.6405182480812073, Train Acc : 77.58399963378906
# Test Loss :0.5171160697937012, Test Acc: 82.68000030517578
# Best Acc : 82.68000030517578
#
# Epoch : 11/300, Learning Rate : 0.009980437345802784
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.45004973, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.52it/s, test_loss_batch=tf.Tensor(0.90416765, shape=(), dtype=float32)]
# Train Loss : 0.607079029083252, Train Acc : 79.09400177001953
# Test Loss :0.49050331115722656, Test Acc: 83.58000183105469
# Best Acc : 83.58000183105469
#
# Epoch : 12/300, Learning Rate : 0.009978486225008965
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.40825868, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(0.87117726, shape=(), dtype=float32)]
# Train Loss : 0.5774901509284973, Train Acc : 79.9739990234375
# Test Loss :0.48215237259864807, Test Acc: 83.6300048828125
# Best Acc : 83.6300048828125
#
# Epoch : 13/300, Learning Rate : 0.009976535104215145
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.43714085, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.32it/s, test_loss_batch=tf.Tensor(0.9045021, shape=(), dtype=float32)]
# Train Loss : 0.5549831390380859, Train Acc : 80.6240005493164
# Test Loss :0.4736810624599457, Test Acc: 84.0
# Best Acc : 84.0
#
# Epoch : 14/300, Learning Rate : 0.0099745849147439
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.16it/s, train_loss_batch=tf.Tensor(0.35298294, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.51it/s, test_loss_batch=tf.Tensor(0.937442, shape=(), dtype=float32)]
# Train Loss : 0.5334287881851196, Train Acc : 81.4800033569336
# Test Loss :0.4480381906032562, Test Acc: 85.04999542236328
# Best Acc : 85.04999542236328
#
# Epoch : 15/300, Learning Rate : 0.00997263565659523
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.18it/s, train_loss_batch=tf.Tensor(0.28665966, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(0.86552036, shape=(), dtype=float32)]
# Train Loss : 0.5117583274841309, Train Acc : 82.3740005493164
# Test Loss :0.44796544313430786, Test Acc: 85.08999633789062
# Best Acc : 85.08999633789062
#
# Epoch : 16/300, Learning Rate : 0.009970685467123985
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.3606593, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.79it/s, test_loss_batch=tf.Tensor(1.0580549, shape=(), dtype=float32)]
# Train Loss : 0.4946165680885315, Train Acc : 82.73199462890625
# Test Loss :0.44813624024391174, Test Acc: 84.89999389648438
# Best Acc : 85.08999633789062
#
# Epoch : 17/300, Learning Rate : 0.00996873714029789
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.43202773, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.44it/s, test_loss_batch=tf.Tensor(0.8633677, shape=(), dtype=float32)]
# Train Loss : 0.4777306914329529, Train Acc : 83.36599731445312
# Test Loss :0.42986860871315, Test Acc: 85.52999877929688
# Best Acc : 85.52999877929688
#
# Epoch : 18/300, Learning Rate : 0.009966790676116943
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.3498255, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.42it/s, test_loss_batch=tf.Tensor(0.8938466, shape=(), dtype=float32)]
# Train Loss : 0.4621419310569763, Train Acc : 83.8740005493164
# Test Loss :0.42606377601623535, Test Acc: 85.40999603271484
# Best Acc : 85.52999877929688
#
# Epoch : 19/300, Learning Rate : 0.009964844211935997
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.28109428, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.57it/s, test_loss_batch=tf.Tensor(0.8218285, shape=(), dtype=float32)]
# Train Loss : 0.4428071081638336, Train Acc : 84.52999877929688
# Test Loss :0.3999445140361786, Test Acc: 86.68000030517578
# Best Acc : 86.68000030517578
#
# Epoch : 20/300, Learning Rate : 0.00996289774775505
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.34039843, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.38it/s, test_loss_batch=tf.Tensor(0.963095, shape=(), dtype=float32)]
# Train Loss : 0.4371078312397003, Train Acc : 84.79199981689453
# Test Loss :0.4042595326900482, Test Acc: 86.5999984741211
# Best Acc : 86.68000030517578
#
# Epoch : 21/300, Learning Rate : 0.009960953146219254
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.27420145, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.31it/s, test_loss_batch=tf.Tensor(0.9114332, shape=(), dtype=float32)]
# Train Loss : 0.4174094796180725, Train Acc : 85.61000061035156
# Test Loss :0.3964335322380066, Test Acc: 86.73999786376953
# Best Acc : 86.73999786376953
#
# Epoch : 22/300, Learning Rate : 0.009959007613360882
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.38188013, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.50it/s, test_loss_batch=tf.Tensor(0.5502536, shape=(), dtype=float32)]
# Train Loss : 0.40727996826171875, Train Acc : 85.9739990234375
# Test Loss :0.378481388092041, Test Acc: 86.90999603271484
# Best Acc : 86.90999603271484
#
# Epoch : 23/300, Learning Rate : 0.009957064874470234
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.20424438, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.28it/s, test_loss_batch=tf.Tensor(0.85972244, shape=(), dtype=float32)]
# Train Loss : 0.39145568013191223, Train Acc : 86.41399383544922
# Test Loss :0.3805546760559082, Test Acc: 87.23999786376953
# Best Acc : 87.23999786376953
#
# Epoch : 24/300, Learning Rate : 0.009955122135579586
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.2605155, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(0.7131648, shape=(), dtype=float32)]
# Train Loss : 0.3859464228153229, Train Acc : 86.50800323486328
# Test Loss :0.38057368993759155, Test Acc: 87.33999633789062
# Best Acc : 87.33999633789062
#
# Epoch : 25/300, Learning Rate : 0.009953180328011513
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.21021561, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.65it/s, test_loss_batch=tf.Tensor(0.9450838, shape=(), dtype=float32)]
# Train Loss : 0.3686692714691162, Train Acc : 87.19000244140625
# Test Loss :0.3846145570278168, Test Acc: 87.44999694824219
# Best Acc : 87.44999694824219
#
# Epoch : 26/300, Learning Rate : 0.00995123852044344
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.17it/s, train_loss_batch=tf.Tensor(0.2652945, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.36it/s, test_loss_batch=tf.Tensor(0.78433335, shape=(), dtype=float32)]
# Train Loss : 0.3667101263999939, Train Acc : 87.25399780273438
# Test Loss :0.36471498012542725, Test Acc: 87.87999725341797
# Best Acc : 87.87999725341797
#
# Epoch : 27/300, Learning Rate : 0.009949298575520515
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.2791545, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(0.75196433, shape=(), dtype=float32)]
# Train Loss : 0.35151365399360657, Train Acc : 87.697998046875
# Test Loss :0.3688475489616394, Test Acc: 87.5199966430664
# Best Acc : 87.87999725341797
#
# Epoch : 28/300, Learning Rate : 0.009947357699275017
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.12952271, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.57it/s, test_loss_batch=tf.Tensor(0.49068817, shape=(), dtype=float32)]
# Train Loss : 0.3459448516368866, Train Acc : 87.98200225830078
# Test Loss :0.35714036226272583, Test Acc: 87.70999908447266
# Best Acc : 87.87999725341797
#
# Epoch : 29/300, Learning Rate : 0.009945418685674667
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.23845975, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.64it/s, test_loss_batch=tf.Tensor(0.37262282, shape=(), dtype=float32)]
# Train Loss : 0.33490943908691406, Train Acc : 88.29399871826172
# Test Loss :0.3521011769771576, Test Acc: 88.0
# Best Acc : 88.0
#
# Epoch : 30/300, Learning Rate : 0.009943480603396893
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.17846766, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.64it/s, test_loss_batch=tf.Tensor(0.805519, shape=(), dtype=float32)]
# Train Loss : 0.32482221722602844, Train Acc : 88.53800201416016
# Test Loss :0.36427462100982666, Test Acc: 88.2300033569336
# Best Acc : 88.2300033569336
#
# Epoch : 31/300, Learning Rate : 0.007456157822161913
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.17it/s, train_loss_batch=tf.Tensor(0.22983149, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(0.69502026, shape=(), dtype=float32)]
# Train Loss : 0.2965199947357178, Train Acc : 89.66600036621094
# Test Loss :0.3405906558036804, Test Acc: 88.87000274658203
# Best Acc : 88.87000274658203
#
# Epoch : 32/300, Learning Rate : 0.0074547054246068
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.2862147, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.67it/s, test_loss_batch=tf.Tensor(0.8007561, shape=(), dtype=float32)]
# Train Loss : 0.288579523563385, Train Acc : 90.02799987792969
# Test Loss :0.3393924832344055, Test Acc: 88.88999938964844
# Best Acc : 88.88999938964844
#
# Epoch : 33/300, Learning Rate : 0.0074532534927129745
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.18it/s, train_loss_batch=tf.Tensor(0.13282509, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.04it/s, test_loss_batch=tf.Tensor(0.7066243, shape=(), dtype=float32)]
# Train Loss : 0.27674582600593567, Train Acc : 90.36199951171875
# Test Loss :0.3427690863609314, Test Acc: 88.81000518798828
# Best Acc : 88.88999938964844
#
# Epoch : 34/300, Learning Rate : 0.007451801095157862
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.19960229, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.43it/s, test_loss_batch=tf.Tensor(0.69679236, shape=(), dtype=float32)]
# Train Loss : 0.2675071954727173, Train Acc : 90.7280044555664
# Test Loss :0.33755776286125183, Test Acc: 88.9800033569336
# Best Acc : 88.9800033569336
#
# Epoch : 35/300, Learning Rate : 0.007450350560247898
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.07850782, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.52it/s, test_loss_batch=tf.Tensor(1.0040156, shape=(), dtype=float32)]
# Train Loss : 0.2708548903465271, Train Acc : 90.60400390625
# Test Loss :0.3425745368003845, Test Acc: 89.20000457763672
# Best Acc : 89.20000457763672
#
# Epoch : 36/300, Learning Rate : 0.0074489000253379345
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.27it/s, train_loss_batch=tf.Tensor(0.1044667, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.73it/s, test_loss_batch=tf.Tensor(0.8086879, shape=(), dtype=float32)]
# Train Loss : 0.26079195737838745, Train Acc : 90.86800384521484
# Test Loss :0.3428802192211151, Test Acc: 89.02999877929688
# Best Acc : 89.20000457763672
#
# Epoch : 37/300, Learning Rate : 0.0074474504217505455
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.1314418, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.47it/s, test_loss_batch=tf.Tensor(0.69799626, shape=(), dtype=float32)]
# Train Loss : 0.2547966241836548, Train Acc : 91.01200103759766
# Test Loss :0.3352910280227661, Test Acc: 89.61000061035156
# Best Acc : 89.61000061035156
#
# Epoch : 38/300, Learning Rate : 0.007446001749485731
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.15119036, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.67it/s, test_loss_batch=tf.Tensor(0.7029291, shape=(), dtype=float32)]
# Train Loss : 0.24666546285152435, Train Acc : 91.38800048828125
# Test Loss :0.34056225419044495, Test Acc: 89.13999938964844
# Best Acc : 89.61000061035156
#
# Epoch : 39/300, Learning Rate : 0.007444553077220917
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.11800692, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.67it/s, test_loss_batch=tf.Tensor(0.5277311, shape=(), dtype=float32)]
# Train Loss : 0.24517467617988586, Train Acc : 91.43400573730469
# Test Loss :0.32266056537628174, Test Acc: 89.84000396728516
# Best Acc : 89.84000396728516
#
# Epoch : 40/300, Learning Rate : 0.007443104404956102
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.15it/s, train_loss_batch=tf.Tensor(0.090794034, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.36it/s, test_loss_batch=tf.Tensor(0.7944045, shape=(), dtype=float32)]
# Train Loss : 0.2351805865764618, Train Acc : 91.8499984741211
# Test Loss :0.3492620885372162, Test Acc: 89.01000213623047
# Best Acc : 89.84000396728516
#
# Epoch : 41/300, Learning Rate : 0.00744165712967515
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.08915508, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.70it/s, test_loss_batch=tf.Tensor(0.7199787, shape=(), dtype=float32)]
# Train Loss : 0.23743608593940735, Train Acc : 91.63600158691406
# Test Loss :0.3262783885002136, Test Acc: 89.52000427246094
# Best Acc : 89.84000396728516
#
# Epoch : 42/300, Learning Rate : 0.007440210320055485
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.13570485, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.29it/s, test_loss_batch=tf.Tensor(0.49781668, shape=(), dtype=float32)]
# Train Loss : 0.22653865814208984, Train Acc : 92.04000091552734
# Test Loss :0.32436877489089966, Test Acc: 89.24000549316406
# Best Acc : 89.84000396728516
#
# Epoch : 43/300, Learning Rate : 0.007438763976097107
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.1069444, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.54it/s, test_loss_batch=tf.Tensor(0.63565135, shape=(), dtype=float32)]
# Train Loss : 0.23051154613494873, Train Acc : 91.9219970703125
# Test Loss :0.3252701163291931, Test Acc: 89.51000213623047
# Best Acc : 89.84000396728516
#
# Epoch : 44/300, Learning Rate : 0.007437318097800016
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.09589992, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.58it/s, test_loss_batch=tf.Tensor(0.5498458, shape=(), dtype=float32)]
# Train Loss : 0.22387340664863586, Train Acc : 92.0999984741211
# Test Loss :0.3312864601612091, Test Acc: 89.7800064086914
# Best Acc : 89.84000396728516
#
# Epoch : 45/300, Learning Rate : 0.0074358731508255005
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.17it/s, train_loss_batch=tf.Tensor(0.08612169, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.68it/s, test_loss_batch=tf.Tensor(0.45355207, shape=(), dtype=float32)]
# Train Loss : 0.21401099860668182, Train Acc : 92.4260025024414
# Test Loss :0.3248461186885834, Test Acc: 89.5
# Best Acc : 89.84000396728516
#
# Epoch : 46/300, Learning Rate : 0.007434427738189697
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.27it/s, train_loss_batch=tf.Tensor(0.0885588, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.46it/s, test_loss_batch=tf.Tensor(0.9286437, shape=(), dtype=float32)]
# Train Loss : 0.21756084263324738, Train Acc : 92.29000091552734
# Test Loss :0.33987775444984436, Test Acc: 89.41000366210938
# Best Acc : 89.84000396728516
#
# Epoch : 47/300, Learning Rate : 0.007432983722537756
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.045235746, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.59it/s, test_loss_batch=tf.Tensor(0.7826239, shape=(), dtype=float32)]
# Train Loss : 0.20692899823188782, Train Acc : 92.75
# Test Loss :0.327915757894516, Test Acc: 89.84000396728516
# Best Acc : 89.84000396728516
#
# Epoch : 48/300, Learning Rate : 0.007431540172547102
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.17845783, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.70it/s, test_loss_batch=tf.Tensor(0.58244765, shape=(), dtype=float32)]
# Train Loss : 0.20764631032943726, Train Acc : 92.6240005493164
# Test Loss :0.33044618368148804, Test Acc: 89.58000183105469
# Best Acc : 89.84000396728516
#
# Epoch : 49/300, Learning Rate : 0.007430097553879023
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.30it/s, train_loss_batch=tf.Tensor(0.14161387, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.42it/s, test_loss_batch=tf.Tensor(0.5406762, shape=(), dtype=float32)]
# Train Loss : 0.20444634556770325, Train Acc : 92.98999786376953
# Test Loss :0.3239050805568695, Test Acc: 89.68000030517578
# Best Acc : 89.84000396728516
#
# Epoch : 50/300, Learning Rate : 0.0074286554008722305
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.10421202, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.36it/s, test_loss_batch=tf.Tensor(0.46169317, shape=(), dtype=float32)]
# Train Loss : 0.1987980455160141, Train Acc : 93.0320053100586
# Test Loss :0.3260946273803711, Test Acc: 90.02000427246094
# Best Acc : 90.02000427246094
#
# Epoch : 51/300, Learning Rate : 0.0074272132478654385
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.04294412, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.47it/s, test_loss_batch=tf.Tensor(0.791403, shape=(), dtype=float32)]
# Train Loss : 0.19641439616680145, Train Acc : 93.12200164794922
# Test Loss :0.3245285153388977, Test Acc: 90.1300048828125
# Best Acc : 90.1300048828125
#
# Epoch : 52/300, Learning Rate : 0.007425771560519934
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.27it/s, train_loss_batch=tf.Tensor(0.13681993, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.49it/s, test_loss_batch=tf.Tensor(1.2562788, shape=(), dtype=float32)]
# Train Loss : 0.19475390017032623, Train Acc : 93.05999755859375
# Test Loss :0.3347198963165283, Test Acc: 90.06000518798828
# Best Acc : 90.1300048828125
#
# Epoch : 53/300, Learning Rate : 0.0074243308044970036
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.176896, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.46it/s, test_loss_batch=tf.Tensor(1.0319854, shape=(), dtype=float32)]
# Train Loss : 0.18761666119098663, Train Acc : 93.47000122070312
# Test Loss :0.3297191560268402, Test Acc: 90.24000549316406
# Best Acc : 90.24000549316406
#
# Epoch : 54/300, Learning Rate : 0.007422890514135361
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.10559553, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.42it/s, test_loss_batch=tf.Tensor(1.0831475, shape=(), dtype=float32)]
# Train Loss : 0.1849481761455536, Train Acc : 93.47200012207031
# Test Loss :0.3289773464202881, Test Acc: 90.27000427246094
# Best Acc : 90.27000427246094
#
# Epoch : 55/300, Learning Rate : 0.0074214511550962925
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.19it/s, train_loss_batch=tf.Tensor(0.1623515, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.36it/s, test_loss_batch=tf.Tensor(0.82534313, shape=(), dtype=float32)]
# Train Loss : 0.1841491460800171, Train Acc : 93.43600463867188
# Test Loss :0.32316532731056213, Test Acc: 90.16000366210938
# Best Acc : 90.27000427246094
#
# Epoch : 56/300, Learning Rate : 0.007420012261718512
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.114876226, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.25it/s, test_loss_batch=tf.Tensor(0.881656, shape=(), dtype=float32)]
# Train Loss : 0.18043090403079987, Train Acc : 93.66400146484375
# Test Loss :0.33383986353874207, Test Acc: 89.96000671386719
# Best Acc : 90.27000427246094
#
# Epoch : 57/300, Learning Rate : 0.007418573834002018
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.27it/s, train_loss_batch=tf.Tensor(0.111840986, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.23it/s, test_loss_batch=tf.Tensor(0.60892457, shape=(), dtype=float32)]
# Train Loss : 0.1707831770181656, Train Acc : 93.96600341796875
# Test Loss :0.32075822353363037, Test Acc: 90.26000213623047
# Best Acc : 90.27000427246094
#
# Epoch : 58/300, Learning Rate : 0.007417135406285524
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(0.058737397, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.04it/s, test_loss_batch=tf.Tensor(1.1972519, shape=(), dtype=float32)]
# Train Loss : 0.17535103857517242, Train Acc : 93.80599975585938
# Test Loss :0.33290940523147583, Test Acc: 90.11000061035156
# Best Acc : 90.27000427246094
#
# Epoch : 59/300, Learning Rate : 0.007415697909891605
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.14it/s, train_loss_batch=tf.Tensor(0.04274369, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.40it/s, test_loss_batch=tf.Tensor(0.8828804, shape=(), dtype=float32)]
# Train Loss : 0.1735638529062271, Train Acc : 93.84600067138672
# Test Loss :0.3274106979370117, Test Acc: 90.24000549316406
# Best Acc : 90.27000427246094
#
# Epoch : 60/300, Learning Rate : 0.007414261344820261
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.19it/s, train_loss_batch=tf.Tensor(0.15600929, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.13it/s, test_loss_batch=tf.Tensor(1.1806366, shape=(), dtype=float32)]
# Train Loss : 0.1672954559326172, Train Acc : 94.21199798583984
# Test Loss :0.3309698700904846, Test Acc: 90.13999938964844
# Best Acc : 90.27000427246094
#
# Epoch : 61/300, Learning Rate : 0.005559619050472975
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.05845779, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.51it/s, test_loss_batch=tf.Tensor(0.7016678, shape=(), dtype=float32)]
# Train Loss : 0.14931721985340118, Train Acc : 94.72799682617188
# Test Loss :0.32344308495521545, Test Acc: 90.37000274658203
# Best Acc : 90.37000274658203
#
# Epoch : 62/300, Learning Rate : 0.005558542441576719
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.17it/s, train_loss_batch=tf.Tensor(0.033586107, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.43it/s, test_loss_batch=tf.Tensor(0.97418636, shape=(), dtype=float32)]
# Train Loss : 0.1491980105638504, Train Acc : 94.72200012207031
# Test Loss :0.3268737196922302, Test Acc: 90.54000091552734
# Best Acc : 90.54000091552734
#
# Epoch : 63/300, Learning Rate : 0.005557466298341751
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.18it/s, train_loss_batch=tf.Tensor(0.018065134, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.32it/s, test_loss_batch=tf.Tensor(0.9222518, shape=(), dtype=float32)]
# Train Loss : 0.14119012653827667, Train Acc : 95.10800170898438
# Test Loss :0.3246558904647827, Test Acc: 90.54000091552734
# Best Acc : 90.54000091552734
#
# Epoch : 64/300, Learning Rate : 0.005556389689445496
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.04342183, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.31it/s, test_loss_batch=tf.Tensor(1.180653, shape=(), dtype=float32)]
# Train Loss : 0.13690556585788727, Train Acc : 95.1919937133789
# Test Loss :0.3429644703865051, Test Acc: 90.43000030517578
# Best Acc : 90.54000091552734
#
# Epoch : 65/300, Learning Rate : 0.005555314011871815
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.070520565, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.67it/s, test_loss_batch=tf.Tensor(1.0316238, shape=(), dtype=float32)]
# Train Loss : 0.13836300373077393, Train Acc : 95.09000396728516
# Test Loss :0.33210015296936035, Test Acc: 90.48999786376953
# Best Acc : 90.54000091552734
#
# Epoch : 66/300, Learning Rate : 0.0055542392656207085
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.08855686, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.60it/s, test_loss_batch=tf.Tensor(0.93664753, shape=(), dtype=float32)]
# Train Loss : 0.13470441102981567, Train Acc : 95.2760009765625
# Test Loss :0.34125182032585144, Test Acc: 90.58999633789062
# Best Acc : 90.58999633789062
#
# Epoch : 67/300, Learning Rate : 0.005553164519369602
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.09530226, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(1.1014591, shape=(), dtype=float32)]
# Train Loss : 0.13280558586120605, Train Acc : 95.3800048828125
# Test Loss :0.3491114377975464, Test Acc: 90.06999969482422
# Best Acc : 90.58999633789062
#
# Epoch : 68/300, Learning Rate : 0.005552090238779783
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.094829135, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.56it/s, test_loss_batch=tf.Tensor(1.0736432, shape=(), dtype=float32)]
# Train Loss : 0.13048487901687622, Train Acc : 95.39600372314453
# Test Loss :0.3312917649745941, Test Acc: 90.56999969482422
# Best Acc : 90.58999633789062
#
# Epoch : 69/300, Learning Rate : 0.005551016423851252
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.021431949, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.39it/s, test_loss_batch=tf.Tensor(1.0567216, shape=(), dtype=float32)]
# Train Loss : 0.13113433122634888, Train Acc : 95.36399841308594
# Test Loss :0.337734192609787, Test Acc: 90.44999694824219
# Best Acc : 90.58999633789062
#
# Epoch : 70/300, Learning Rate : 0.00554994260892272
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.30it/s, train_loss_batch=tf.Tensor(0.027286509, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.59it/s, test_loss_batch=tf.Tensor(1.0697558, shape=(), dtype=float32)]
# Train Loss : 0.1266142576932907, Train Acc : 95.51599884033203
# Test Loss :0.341727077960968, Test Acc: 90.38999938964844
# Best Acc : 90.58999633789062
#
# Epoch : 71/300, Learning Rate : 0.005548869725316763
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.071936265, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.41it/s, test_loss_batch=tf.Tensor(1.1128396, shape=(), dtype=float32)]
# Train Loss : 0.12189886718988419, Train Acc : 95.80799865722656
# Test Loss :0.33463406562805176, Test Acc: 90.58999633789062
# Best Acc : 90.58999633789062
#
# Epoch : 72/300, Learning Rate : 0.005547796841710806
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.067594096, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.61it/s, test_loss_batch=tf.Tensor(0.98007554, shape=(), dtype=float32)]
# Train Loss : 0.12555265426635742, Train Acc : 95.61399841308594
# Test Loss :0.33607277274131775, Test Acc: 90.72000122070312
# Best Acc : 90.72000122070312
#
# Epoch : 73/300, Learning Rate : 0.0055467248894274235
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.037533917, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.64it/s, test_loss_batch=tf.Tensor(0.85678506, shape=(), dtype=float32)]
# Train Loss : 0.11912527680397034, Train Acc : 95.7719955444336
# Test Loss :0.3432890772819519, Test Acc: 90.38999938964844
# Best Acc : 90.72000122070312
#
# Epoch : 74/300, Learning Rate : 0.005545652937144041
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.30it/s, train_loss_batch=tf.Tensor(0.0115493145, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(1.130932, shape=(), dtype=float32)]
# Train Loss : 0.12413918972015381, Train Acc : 95.63999938964844
# Test Loss :0.3396034836769104, Test Acc: 90.69000244140625
# Best Acc : 90.72000122070312
#
# Epoch : 75/300, Learning Rate : 0.005544581916183233
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.0362717, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.50it/s, test_loss_batch=tf.Tensor(0.68468404, shape=(), dtype=float32)]
# Train Loss : 0.11621958017349243, Train Acc : 95.77000427246094
# Test Loss :0.32896310091018677, Test Acc: 90.5999984741211
# Best Acc : 90.72000122070312
#
# Epoch : 76/300, Learning Rate : 0.005543510429561138
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.03772313, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.50it/s, test_loss_batch=tf.Tensor(1.1852126, shape=(), dtype=float32)]
# Train Loss : 0.1174643486738205, Train Acc : 95.81600189208984
# Test Loss :0.33458003401756287, Test Acc: 90.94999694824219
# Best Acc : 90.94999694824219
#
# Epoch : 77/300, Learning Rate : 0.005542439874261618
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.14it/s, train_loss_batch=tf.Tensor(0.03952024, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(0.6812047, shape=(), dtype=float32)]
# Train Loss : 0.11475008726119995, Train Acc : 96.05000305175781
# Test Loss :0.3299173414707184, Test Acc: 90.5999984741211
# Best Acc : 90.94999694824219
#
# Epoch : 78/300, Learning Rate : 0.0055413697846233845
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.07086401, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.63it/s, test_loss_batch=tf.Tensor(0.9842869, shape=(), dtype=float32)]
# Train Loss : 0.11302521079778671, Train Acc : 96.11000061035156
# Test Loss :0.3470015227794647, Test Acc: 90.4800033569336
# Best Acc : 90.94999694824219
#
# Epoch : 79/300, Learning Rate : 0.005540300160646439
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.056043673, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.67it/s, test_loss_batch=tf.Tensor(0.84321725, shape=(), dtype=float32)]
# Train Loss : 0.11318416148424149, Train Acc : 96.13199615478516
# Test Loss :0.3374740183353424, Test Acc: 90.6500015258789
# Best Acc : 90.94999694824219
#
# Epoch : 80/300, Learning Rate : 0.00553923100233078
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.27it/s, train_loss_batch=tf.Tensor(0.044786803, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.22it/s, test_loss_batch=tf.Tensor(1.0703036, shape=(), dtype=float32)]
# Train Loss : 0.10960917919874191, Train Acc : 96.11599731445312
# Test Loss :0.345587819814682, Test Acc: 90.6500015258789
# Best Acc : 90.94999694824219
#
# Epoch : 81/300, Learning Rate : 0.005538162309676409
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.17it/s, train_loss_batch=tf.Tensor(0.019237269, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.67it/s, test_loss_batch=tf.Tensor(1.1736699, shape=(), dtype=float32)]
# Train Loss : 0.10701467841863632, Train Acc : 96.21599578857422
# Test Loss :0.3545166850090027, Test Acc: 90.4000015258789
# Best Acc : 90.94999694824219
#
# Epoch : 82/300, Learning Rate : 0.00553709315136075
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.037577722, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.54it/s, test_loss_batch=tf.Tensor(1.6369478, shape=(), dtype=float32)]
# Train Loss : 0.10803645104169846, Train Acc : 96.22599792480469
# Test Loss :0.37130969762802124, Test Acc: 90.56999969482422
# Best Acc : 90.94999694824219
#
# Epoch : 83/300, Learning Rate : 0.005536024924367666
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.017693255, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.55it/s, test_loss_batch=tf.Tensor(1.1520202, shape=(), dtype=float32)]
# Train Loss : 0.10785267502069473, Train Acc : 96.16600036621094
# Test Loss :0.3339638113975525, Test Acc: 91.02999877929688
# Best Acc : 91.02999877929688
#
# Epoch : 84/300, Learning Rate : 0.005534957628697157
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.03768359, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.38it/s, test_loss_batch=tf.Tensor(1.5637994, shape=(), dtype=float32)]
# Train Loss : 0.10176708549261093, Train Acc : 96.33000183105469
# Test Loss :0.3645853102207184, Test Acc: 90.62999725341797
# Best Acc : 91.02999877929688
#
# Epoch : 85/300, Learning Rate : 0.005533890333026648
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.14it/s, train_loss_batch=tf.Tensor(0.050597798, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.45it/s, test_loss_batch=tf.Tensor(1.4167873, shape=(), dtype=float32)]
# Train Loss : 0.10541759431362152, Train Acc : 96.24400329589844
# Test Loss :0.3535446524620056, Test Acc: 90.79000091552734
# Best Acc : 91.02999877929688
#
# Epoch : 86/300, Learning Rate : 0.0055328235030174255
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.02170369, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.18it/s, test_loss_batch=tf.Tensor(1.0843072, shape=(), dtype=float32)]
# Train Loss : 0.10256706923246384, Train Acc : 96.38800048828125
# Test Loss :0.34773701429367065, Test Acc: 90.77999877929688
# Best Acc : 91.02999877929688
#
# Epoch : 87/300, Learning Rate : 0.005531757138669491
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.046473775, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.39it/s, test_loss_batch=tf.Tensor(1.10415, shape=(), dtype=float32)]
# Train Loss : 0.10121122747659683, Train Acc : 96.40399932861328
# Test Loss :0.3457512855529785, Test Acc: 90.83000183105469
# Best Acc : 91.02999877929688
#
# Epoch : 88/300, Learning Rate : 0.005530690774321556
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.18it/s, train_loss_batch=tf.Tensor(0.036121316, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.72it/s, test_loss_batch=tf.Tensor(1.0166669, shape=(), dtype=float32)]
# Train Loss : 0.10312340408563614, Train Acc : 96.48400115966797
# Test Loss :0.34886765480041504, Test Acc: 90.51000213623047
# Best Acc : 91.02999877929688
#
# Epoch : 89/300, Learning Rate : 0.005529624875634909
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.03827879, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.47it/s, test_loss_batch=tf.Tensor(1.217104, shape=(), dtype=float32)]
# Train Loss : 0.10129325091838837, Train Acc : 96.447998046875
# Test Loss :0.3450604975223541, Test Acc: 90.79000091552734
# Best Acc : 91.02999877929688
#
# Epoch : 90/300, Learning Rate : 0.005528559908270836
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.012649131, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.43it/s, test_loss_batch=tf.Tensor(1.3334987, shape=(), dtype=float32)]
# Train Loss : 0.09738137573003769, Train Acc : 96.63199615478516
# Test Loss :0.3612079918384552, Test Acc: 90.61000061035156
# Best Acc : 91.02999877929688
#
# Epoch : 91/300, Learning Rate : 0.004145621322095394
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(0.020709014, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.46it/s, test_loss_batch=tf.Tensor(1.2594078, shape=(), dtype=float32)]
# Train Loss : 0.08993726968765259, Train Acc : 96.9000015258789
# Test Loss :0.34921252727508545, Test Acc: 90.81999969482422
# Best Acc : 91.02999877929688
#
# Epoch : 92/300, Learning Rate : 0.004144823178648949
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.03034116, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.56it/s, test_loss_batch=tf.Tensor(1.3904595, shape=(), dtype=float32)]
# Train Loss : 0.08724001795053482, Train Acc : 96.9780044555664
# Test Loss :0.3446792960166931, Test Acc: 91.28999328613281
# Best Acc : 91.28999328613281
#
# Epoch : 93/300, Learning Rate : 0.0041440255008637905
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.04379662, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.24it/s, test_loss_batch=tf.Tensor(1.2892244, shape=(), dtype=float32)]
# Train Loss : 0.08306370675563812, Train Acc : 97.10599517822266
# Test Loss :0.34551340341567993, Test Acc: 91.11000061035156
# Best Acc : 91.28999328613281
#
# Epoch : 94/300, Learning Rate : 0.004143227357417345
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.058545686, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.47it/s, test_loss_batch=tf.Tensor(1.4309032, shape=(), dtype=float32)]
# Train Loss : 0.08137553930282593, Train Acc : 97.12799835205078
# Test Loss :0.35809269547462463, Test Acc: 90.95999908447266
# Best Acc : 91.28999328613281
#
# Epoch : 95/300, Learning Rate : 0.004142429679632187
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.04182883, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.59it/s, test_loss_batch=tf.Tensor(1.1048412, shape=(), dtype=float32)]
# Train Loss : 0.08244027942419052, Train Acc : 97.197998046875
# Test Loss :0.34588780999183655, Test Acc: 90.95999908447266
# Best Acc : 91.28999328613281
#
# Epoch : 96/300, Learning Rate : 0.004141632933169603
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.0315622, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(0.8559315, shape=(), dtype=float32)]
# Train Loss : 0.08041201531887054, Train Acc : 97.23400115966797
# Test Loss :0.34268397092819214, Test Acc: 90.94999694824219
# Best Acc : 91.28999328613281
#
# Epoch : 97/300, Learning Rate : 0.00414083618670702
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.046048358, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.59it/s, test_loss_batch=tf.Tensor(1.0781097, shape=(), dtype=float32)]
# Train Loss : 0.07654323428869247, Train Acc : 97.26799774169922
# Test Loss :0.34819355607032776, Test Acc: 91.1199951171875
# Best Acc : 91.28999328613281
#
# Epoch : 98/300, Learning Rate : 0.004140039905905724
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.31it/s, train_loss_batch=tf.Tensor(0.059367914, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.44it/s, test_loss_batch=tf.Tensor(1.1008556, shape=(), dtype=float32)]
# Train Loss : 0.08124879747629166, Train Acc : 97.1520004272461
# Test Loss :0.34957945346832275, Test Acc: 90.83999633789062
# Best Acc : 91.28999328613281
#
# Epoch : 99/300, Learning Rate : 0.004139243625104427
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.004814218, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(0.806418, shape=(), dtype=float32)]
# Train Loss : 0.07749529927968979, Train Acc : 97.23799896240234
# Test Loss :0.33851462602615356, Test Acc: 90.94999694824219
# Best Acc : 91.28999328613281
#
# Epoch : 100/300, Learning Rate : 0.004138447344303131
# TRAINING...
# ...
# Testing...
# 100% 40/40 [00:01<00:00, 36.61it/s, test_loss_batch=tf.Tensor(1.3604586, shape=(), dtype=float32)]
# Train Loss : 0.01612061820924282, Train Acc : 99.45399475097656
# Test Loss :0.4066523611545563, Test Acc: 92.05999755859375
# Best Acc : 92.07999420166016
#
# Epoch : 265/300, Learning Rate : 0.0009518753504380584
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.23it/s, train_loss_batch=tf.Tensor(0.0010574614, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.79it/s, test_loss_batch=tf.Tensor(1.5857074, shape=(), dtype=float32)]
# Train Loss : 0.014682873152196407, Train Acc : 99.50799560546875
# Test Loss :0.4145534038543701, Test Acc: 91.83999633789062
# Best Acc : 92.07999420166016
#
# Epoch : 266/300, Learning Rate : 0.000951697991695255
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.13it/s, train_loss_batch=tf.Tensor(0.0011815593, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.49it/s, test_loss_batch=tf.Tensor(1.5158887, shape=(), dtype=float32)]
# Train Loss : 0.015246165916323662, Train Acc : 99.46600341796875
# Test Loss :0.42209911346435547, Test Acc: 91.77999877929688
# Best Acc : 92.07999420166016
#
# Epoch : 267/300, Learning Rate : 0.0009515207493677735
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(8.669552e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.76it/s, test_loss_batch=tf.Tensor(1.833575, shape=(), dtype=float32)]
# Train Loss : 0.014539031311869621, Train Acc : 99.52200317382812
# Test Loss :0.4308909475803375, Test Acc: 91.82999420166016
# Best Acc : 92.07999420166016
#
# Epoch : 268/300, Learning Rate : 0.0009513433906249702
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.00066870474, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 30.34it/s, test_loss_batch=tf.Tensor(1.6561098, shape=(), dtype=float32)]
# Train Loss : 0.01581762358546257, Train Acc : 99.49800109863281
# Test Loss :0.4244958758354187, Test Acc: 91.91999816894531
# Best Acc : 92.07999420166016
#
# Epoch : 269/300, Learning Rate : 0.0009511662647128105
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.30it/s, train_loss_batch=tf.Tensor(0.00077684195, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(1.7356993, shape=(), dtype=float32)]
# Train Loss : 0.016219481825828552, Train Acc : 99.46600341796875
# Test Loss :0.42676782608032227, Test Acc: 91.86000061035156
# Best Acc : 92.07999420166016
#
# Epoch : 270/300, Learning Rate : 0.0009509891970083117
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.29it/s, train_loss_batch=tf.Tensor(0.0014471682, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.49it/s, test_loss_batch=tf.Tensor(1.8936683, shape=(), dtype=float32)]
# Train Loss : 0.01730981282889843, Train Acc : 99.38800048828125
# Test Loss :0.43058037757873535, Test Acc: 91.79000091552734
# Best Acc : 92.07999420166016
#
# Epoch : 271/300, Learning Rate : 0.0007131091551855206
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(3.4144796e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.73it/s, test_loss_batch=tf.Tensor(2.0076208, shape=(), dtype=float32)]
# Train Loss : 0.015192985534667969, Train Acc : 99.47000122070312
# Test Loss :0.4266131520271301, Test Acc: 91.93999481201172
# Best Acc : 92.07999420166016
#
# Epoch : 272/300, Learning Rate : 0.0007129764417186379
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.0009884376, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.69it/s, test_loss_batch=tf.Tensor(1.8684349, shape=(), dtype=float32)]
# Train Loss : 0.015937086194753647, Train Acc : 99.48400115966797
# Test Loss :0.42475518584251404, Test Acc: 91.93999481201172
# Best Acc : 92.07999420166016
#
# Epoch : 273/300, Learning Rate : 0.0007128437864594162
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.0018416417, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.62it/s, test_loss_batch=tf.Tensor(1.7534565, shape=(), dtype=float32)]
# Train Loss : 0.014503169804811478, Train Acc : 99.49600219726562
# Test Loss :0.41975027322769165, Test Acc: 92.0
# Best Acc : 92.07999420166016
#
# Epoch : 274/300, Learning Rate : 0.0007127110729925334
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.0018397175, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.59it/s, test_loss_batch=tf.Tensor(1.9462901, shape=(), dtype=float32)]
# Train Loss : 0.013452403247356415, Train Acc : 99.55000305175781
# Test Loss :0.4240598678588867, Test Acc: 91.94999694824219
# Best Acc : 92.07999420166016
#
# Epoch : 275/300, Learning Rate : 0.0007125785341486335
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.0013158413, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 30.33it/s, test_loss_batch=tf.Tensor(1.6460254, shape=(), dtype=float32)]
# Train Loss : 0.014078756794333458, Train Acc : 99.51000213623047
# Test Loss :0.41761475801467896, Test Acc: 91.93999481201172
# Best Acc : 92.07999420166016
#
# Epoch : 276/300, Learning Rate : 0.0007124460535123944
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(0.0002072939, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(1.7765617, shape=(), dtype=float32)]
# Train Loss : 0.014286703430116177, Train Acc : 99.49200439453125
# Test Loss :0.4263710379600525, Test Acc: 91.91999816894531
# Best Acc : 92.07999420166016
#
# Epoch : 277/300, Learning Rate : 0.0007123135728761554
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(0.005304248, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.74it/s, test_loss_batch=tf.Tensor(1.8528035, shape=(), dtype=float32)]
# Train Loss : 0.01426856778562069, Train Acc : 99.47000122070312
# Test Loss :0.4245936870574951, Test Acc: 91.90999603271484
# Best Acc : 92.07999420166016
#
# Epoch : 278/300, Learning Rate : 0.0007121811504475772
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(0.00013169387, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.39it/s, test_loss_batch=tf.Tensor(1.2668077, shape=(), dtype=float32)]
# Train Loss : 0.015353973954916, Train Acc : 99.48400115966797
# Test Loss :0.41021794080734253, Test Acc: 91.97000122070312
# Best Acc : 92.07999420166016
#
# Epoch : 279/300, Learning Rate : 0.00071204878622666
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(0.00012081528, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.53it/s, test_loss_batch=tf.Tensor(1.7485769, shape=(), dtype=float32)]
# Train Loss : 0.012840252369642258, Train Acc : 99.55799865722656
# Test Loss :0.4263646602630615, Test Acc: 91.82999420166016
# Best Acc : 92.07999420166016
#
# Epoch : 280/300, Learning Rate : 0.0007119164220057428
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.20it/s, train_loss_batch=tf.Tensor(0.008773102, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.64it/s, test_loss_batch=tf.Tensor(1.5872072, shape=(), dtype=float32)]
# Train Loss : 0.013407556340098381, Train Acc : 99.52399444580078
# Test Loss :0.42236655950546265, Test Acc: 92.11000061035156
# Best Acc : 92.11000061035156
#
# Epoch : 281/300, Learning Rate : 0.0007117841159924865
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.19it/s, train_loss_batch=tf.Tensor(0.0005965723, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.46it/s, test_loss_batch=tf.Tensor(1.6046696, shape=(), dtype=float32)]
# Train Loss : 0.014706245623528957, Train Acc : 99.48999786376953
# Test Loss :0.424848735332489, Test Acc: 92.0199966430664
# Best Acc : 92.11000061035156
#
# Epoch : 282/300, Learning Rate : 0.000711651926394552
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.30it/s, train_loss_batch=tf.Tensor(0.00022091522, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.44it/s, test_loss_batch=tf.Tensor(1.5538675, shape=(), dtype=float32)]
# Train Loss : 0.012189769186079502, Train Acc : 99.59400177001953
# Test Loss :0.4223429262638092, Test Acc: 92.05999755859375
# Best Acc : 92.11000061035156
#
# Epoch : 283/300, Learning Rate : 0.0007115197367966175
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.047734983, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.50it/s, test_loss_batch=tf.Tensor(1.8403006, shape=(), dtype=float32)]
# Train Loss : 0.013990226201713085, Train Acc : 99.53600311279297
# Test Loss :0.43446865677833557, Test Acc: 92.04000091552734
# Best Acc : 92.11000061035156
#
# Epoch : 284/300, Learning Rate : 0.0007113876636140049
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(0.00020046758, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.38it/s, test_loss_batch=tf.Tensor(1.5665996, shape=(), dtype=float32)]
# Train Loss : 0.014000443741679192, Train Acc : 99.53800201416016
# Test Loss :0.42354029417037964, Test Acc: 92.00999450683594
# Best Acc : 92.11000061035156
#
# Epoch : 285/300, Learning Rate : 0.0007112555904313922
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.22it/s, train_loss_batch=tf.Tensor(9.9633704e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.36it/s, test_loss_batch=tf.Tensor(1.6159616, shape=(), dtype=float32)]
# Train Loss : 0.013117791153490543, Train Acc : 99.5479965209961
# Test Loss :0.42366355657577515, Test Acc: 91.94999694824219
# Best Acc : 92.11000061035156
#
# Epoch : 286/300, Learning Rate : 0.0007111234590411186
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.21it/s, train_loss_batch=tf.Tensor(0.0013668921, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.12it/s, test_loss_batch=tf.Tensor(1.5029612, shape=(), dtype=float32)]
# Train Loss : 0.014643708243966103, Train Acc : 99.49600219726562
# Test Loss :0.4222654402256012, Test Acc: 91.93000030517578
# Best Acc : 92.11000061035156
#
# Epoch : 287/300, Learning Rate : 0.0007109915022738278
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.18it/s, train_loss_batch=tf.Tensor(0.00036550523, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.55it/s, test_loss_batch=tf.Tensor(1.6631455, shape=(), dtype=float32)]
# Train Loss : 0.014134032651782036, Train Acc : 99.52799987792969
# Test Loss :0.4235869348049164, Test Acc: 92.0199966430664
# Best Acc : 92.11000061035156
#
# Epoch : 288/300, Learning Rate : 0.0007108596037141979
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.021354929, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.51it/s, test_loss_batch=tf.Tensor(1.6987939, shape=(), dtype=float32)]
# Train Loss : 0.01294973585754633, Train Acc : 99.54199981689453
# Test Loss :0.42750078439712524, Test Acc: 91.94999694824219
# Best Acc : 92.11000061035156
#
# Epoch : 289/300, Learning Rate : 0.000710727705154568
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.00017266226, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.61it/s, test_loss_batch=tf.Tensor(1.4379816, shape=(), dtype=float32)]
# Train Loss : 0.012065141461789608, Train Acc : 99.56600189208984
# Test Loss :0.42240795493125916, Test Acc: 92.06999969482422
# Best Acc : 92.11000061035156
#
# Epoch : 290/300, Learning Rate : 0.0007105959230102599
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.33it/s, train_loss_batch=tf.Tensor(0.00028324037, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.66it/s, test_loss_batch=tf.Tensor(1.7568351, shape=(), dtype=float32)]
# Train Loss : 0.014951773919165134, Train Acc : 99.49800109863281
# Test Loss :0.4312307834625244, Test Acc: 91.88999938964844
# Best Acc : 92.11000061035156
#
# Epoch : 291/300, Learning Rate : 0.0007104641408659518
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.16it/s, train_loss_batch=tf.Tensor(9.250722e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.39it/s, test_loss_batch=tf.Tensor(1.7150631, shape=(), dtype=float32)]
# Train Loss : 0.01265233289450407, Train Acc : 99.57600402832031
# Test Loss :0.42841511964797974, Test Acc: 91.97999572753906
# Best Acc : 92.11000061035156
#
# Epoch : 292/300, Learning Rate : 0.0007103323005139828
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.19it/s, train_loss_batch=tf.Tensor(0.002813472, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.59it/s, test_loss_batch=tf.Tensor(1.66574, shape=(), dtype=float32)]
# Train Loss : 0.01367654837667942, Train Acc : 99.52799987792969
# Test Loss :0.4271863102912903, Test Acc: 91.8499984741211
# Best Acc : 92.11000061035156
#
# Epoch : 293/300, Learning Rate : 0.0007102006347849965
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.24it/s, train_loss_batch=tf.Tensor(8.627791e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.48it/s, test_loss_batch=tf.Tensor(1.6505827, shape=(), dtype=float32)]
# Train Loss : 0.0146554633975029, Train Acc : 99.51200103759766
# Test Loss :0.4258653223514557, Test Acc: 91.82999420166016
# Best Acc : 92.11000061035156
#
# Epoch : 294/300, Learning Rate : 0.0007100690272636712
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.27it/s, train_loss_batch=tf.Tensor(0.0070011304, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.45it/s, test_loss_batch=tf.Tensor(1.7305603, shape=(), dtype=float32)]
# Train Loss : 0.01287111546844244, Train Acc : 99.58799743652344
# Test Loss :0.42780986428260803, Test Acc: 92.15999603271484
# Best Acc : 92.15999603271484
#
# Epoch : 295/300, Learning Rate : 0.0007099374197423458
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(3.1369873e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.55it/s, test_loss_batch=tf.Tensor(1.7102273, shape=(), dtype=float32)]
# Train Loss : 0.013272047974169254, Train Acc : 99.55000305175781
# Test Loss :0.4315342903137207, Test Acc: 91.94999694824219
# Best Acc : 92.15999603271484
#
# Epoch : 296/300, Learning Rate : 0.0007098059286363423
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.25it/s, train_loss_batch=tf.Tensor(0.016120568, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.60it/s, test_loss_batch=tf.Tensor(1.8137958, shape=(), dtype=float32)]
# Train Loss : 0.013038024306297302, Train Acc : 99.5199966430664
# Test Loss :0.4365394115447998, Test Acc: 91.97000122070312
# Best Acc : 92.15999603271484
#
# Epoch : 297/300, Learning Rate : 0.0007096744375303388
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.33it/s, train_loss_batch=tf.Tensor(0.01888317, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.41it/s, test_loss_batch=tf.Tensor(1.6994262, shape=(), dtype=float32)]
# Train Loss : 0.014048959128558636, Train Acc : 99.5
# Test Loss :0.43091803789138794, Test Acc: 92.0199966430664
# Best Acc : 92.15999603271484
#
# Epoch : 298/300, Learning Rate : 0.0007095429464243352
# TRAINING...
# 100% 196/196 [00:16<00:00, 12.25it/s, train_loss_batch=tf.Tensor(5.15551e-05, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.32it/s, test_loss_batch=tf.Tensor(1.9117073, shape=(), dtype=float32)]
# Train Loss : 0.013366537168622017, Train Acc : 99.53800201416016
# Test Loss :0.44104257225990295, Test Acc: 92.05999755859375
# Best Acc : 92.15999603271484
#
# Epoch : 299/300, Learning Rate : 0.0007094115717336535
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.28it/s, train_loss_batch=tf.Tensor(0.00046233746, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.70it/s, test_loss_batch=tf.Tensor(1.8708558, shape=(), dtype=float32)]
# Train Loss : 0.013172385282814503, Train Acc : 99.53600311279297
# Test Loss :0.4373122751712799, Test Acc: 92.06999969482422
# Best Acc : 92.15999603271484
#
# Epoch : 300/300, Learning Rate : 0.0007092801970429718
# TRAINING...
# 100% 196/196 [00:15<00:00, 12.26it/s, train_loss_batch=tf.Tensor(0.0047654654, shape=(), dtype=float32)]
# Testing...
# 100% 40/40 [00:01<00:00, 36.64it/s, test_loss_batch=tf.Tensor(1.8636558, shape=(), dtype=float32)]
# Train Loss : 0.01543175708502531, Train Acc : 99.50199890136719
# Test Loss :0.4334287643432617, Test Acc: 92.04000091552734
# Best Acc : 92.15999603271484

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.datasets import cifar10
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from get_model import get_model


# def normalization(train_images, test_images):
#     mean = np.mean(train_images, axis=(0, 1, 2, 3))
#     std = np.std(train_images, axis=(0, 1, 2, 3))
#     train_images = (train_images - mean) / (std + 1e-7)
#     test_images = (test_images - mean) / (std + 1e-7)
#     return train_images, test_images


# def load_images():
#     (train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

#     train_images = train_images.astype(np.float32)
#     test_images = test_images.astype(np.float32)

#     (train_images, test_images) = normalization(train_images, test_images)

#     train_labels = to_categorical(train_labels, 10)
#     test_labels = to_categorical(test_labels, 10)

#     # train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).shuffle(
#     #     buffer_size=10000).batch(batch_size)
#     # test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

#     return train_images, train_labels, test_images, test_labels
# if __name__ == '__main__':
#     print(tf.__version__)
#     print(keras.__version__)

#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     if gpus:
#         # 텐서플로가 첫 번째 GPU만 사용하도록 제한
#         try:
#             print('start with GPU 7')
#             tf.config.experimental.set_visible_devices(gpus[7], 'GPU')
#             tf.config.experimental.set_memory_growth(gpus[7], True)
#         except RuntimeError as e:
#             # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
#             print(e)

#     training_epochs = 250
#     batch_size = 128
#     learning_rate = 0.1
#     momentum = 0.9
#     lr_decay = 1e-6
#     lr_drop = 20

#     tf.random.set_seed(777)

#     def lr_scheduler(epoch):
#         return learning_rate * (0.5 ** (epoch // lr_drop))

#     reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

#     train_images, train_labels, test_images, test_labels = load_images()

#     # data augmentation
#     datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip=True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images
#     # (std, mean, and principal components if ZCA whitening is applied).
#     datagen.fit(train_images)

#     model = get_model('vgg11')

#     optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate,
#                                         decay=1e-6, momentum=momentum, nesterov=True)
#     model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

#     model.fit_generator(datagen.flow(train_images, train_labels,
#                                      batch_size=batch_size), epochs=training_epochs, verbose=2, callbacks=[reduce_lr],
#                         steps_per_epoch=train_images.shape[0] // batch_size, validation_data=(test_images, test_labels))

#     model.save_weights('cifar10vgg_custom.h5')
